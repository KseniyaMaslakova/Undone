# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import pylab as pl

#обработка
from sklearn.preprocessing import MinMaxScaler
from imblearn.over_sampling import SMOTE

# модели
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB, MultinomialNB, CategoricalNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline

# метрики качества модели
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from yellowbrick.classifier import ROCAUC, PrecisionRecallCurve

# улучшение модели
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from yellowbrick.model_selection import LearningCurve

# %%
df = pd.read_csv('final.csv')
df.head()
# Out:
#      class    av_flat  min_ceiling_h  parking_ratio  infr_access  lift_ratio
# 0  Типовой  44.460000           2.70       0.000000            5    0.000000
# 1  Комфорт  69.358974           2.95       1.426282            8   46.800000
# 2  Комфорт  37.243697           2.70       1.878151            8   69.133333
# 3  Комфорт  40.970794           2.72       0.964953            5   72.004706
# 4  Комфорт  40.695195           2.72       1.040541            6   70.027941

# %% [markdown]
# # Итоговый план по машинному обучению:

# %% [markdown]
# - Предсказываем категориальную переменную ‘class’ - класс недвижимости, принимающий значения {'Типовой', 'Комфорт', 'Бизнес', 'Элитный'}. Будет мультиклассовое предсказание, так как у нас есть 4 различных класса.
# - Задача: по совокупности категориальных и дейсвительных признаков определить класс недвижимости (задача классификации)
# - Разделить данные на признаки (x)  и целевую переменную (y)
# - Разделить выборку в соотношении 80/20 - треин/тест
# - Использовать кросс-валидацию
# - Если выборки не хватает: SMOTE (овэрсемплинг)

# %% [markdown]
# ## Модели, которые будем рассматривать при кросс-валидации:

# %% [markdown]
# - **Логистическая регрессия** - хорошо работает с бинарными и многоклассовыми классификациями (может обучать K моделей, каждая из которых отличается только целевым классом)
# -**Наивный байес (категориальный и гауссовский)** - простой и эффективный классификатор, который хорошо подходит для категориальных данных. Легко справляется с большими объёмами данных. Он может использоваться для мультиклассовой классификации, но предполагает независимость признаков, что может быть ограничением в некоторых случаях
# - **Метод опорных векторов без ядра и с гауссовским ядром** - эффективен для классификации с использованием различных ядер. Однако при использовании гауссовского ядра SVM может столкнуться с проблемами масштабирования
# - **Случайный лес** - хорошо работает с большим количеством признаков и способна обрабатывать как категориальные, так и числовые признаки
# - **Градиентный бустинг, Catboost,** может давать хорошие результаты для мультиклассовой классификации. Они могут быть эффективными моделями, особенно при настройке оптимальных параметров
#
# **Модель, которую мы изначально хотели рассматривать, но отказались от них:**
#
# - **KNN** - может использоваться для предсказания категориальных переменных, но плохо работает с большими объемами данных, так как может быть вычислительно затратным при большом количестве признаков (требует вычисления расстояний до всех обучающих примеров), склонен к смещению решения в сторону доминирующего класса.

# %% [markdown]
# ##Метрики

# %% [markdown]
# 1. **Матрица ошибок (Сonfusion matrix)** - матрица, которая показывает сколько объектов каждого класса были распознаны правильно, а сколько - неправильно. На основе матрицы ошибок и её значений, рассчитываются различные метрики классификационной способности алгоритма. Дает наглядно понять, как хорошо работает модель.
# 2. **Меткость (Accuracy)** - доля правильно предсказанных классов. Характеризует качество модели, но зачастую используется в сочетании с другими метриками. Данная метрика часто используется в задачах классификации, когда все классы равноправны и одинаково важны, и нет явного дисбаланса классов. (Так как у нас присутствует дисбаланс классов, то мы все равно посчитаем эту метрику, но не будем опираться на нее при оценке модели)
# 3. **Точность (Precision)** -это метрика оценки качества модели в задачах классификации, которая измеряет долю правильно предсказанных положительных классов относительно всех объектов, которые модель предсказала как положительные. Другими словами, точность дает ответ на вопрос «Из всех объектов, которые классифицированы как принадлежащие классу, сколько на самом деле принадлежит ему?». Наиболее часто используеься когда присутствует дисбаланс классов (поэтому обратим на нее особое внимание).
# 4. **Полнота (Recall)** - пропорция всех верно-положительно предсказанных объектов к общему количеству действительно положительных. То есть, полнота показывает сколько образцов из всех положительных примеров были классифицированы правильно. Наиболее часто используеься когда присутствует дисбаланс классов (поэтому обратим на нее особое внимание).
# 5. **F1-мера (F1-score)** - взвешенное гармоническое среднее полноты и точности. Этот показатель демонстрирует, как много случаев прогнозируется моделью правильно, и сколько истинных экземпляров модель не пропустит.
# 6. **Площадь под ROC-кривой (Area under ROC-curve, AUC-ROC)** - это метрика, используемая в задачах классификации для измерения площади под кривой receiver operating characteristic (ROC). Она оценивает компромисс между частотой истинных и ложных положительных результатов при различных пороговых значениях классификации.
# 7. **Площадь под кривой полнота-точность (Area under precision-recall curve, AUC-PR)** - это метрика, используемая в задачах классификации для измерения площади под кривой "precision-recall". Она обеспечивает комплексную оценку эффективности модели на различных уровнях precision и recall при различных пороговых значениях классификации. Используется, когда необходимо оценить эффективность модели классификации при различных компромиссах между precision и recall и выбрать оптимальное значение порога. Он особенно полезен, когда есть дисбаланс классов.
#
#
# Таким образом, основными метриками, на которых мы сконцентрируемся будут Precision, Recall и F1-score, так как они хорошо работают при дисбалансе классов.

# %% [markdown]
# #Машинное обучение

# %% [markdown]
# ## Разделение переменных

# %% [markdown]
# Разделим данные на признаки X и целевую переменную y.

# %%
X = df.drop(['class'], axis=1)
X.head()
# Out:
#      av_flat  min_ceiling_h  parking_ratio  infr_access  lift_ratio
# 0  44.460000           2.70       0.000000            5    0.000000
# 1  69.358974           2.95       1.426282            8   46.800000
# 2  37.243697           2.70       1.878151            8   69.133333
# 3  40.970794           2.72       0.964953            5   72.004706
# 4  40.695195           2.72       1.040541            6   70.027941

# %%
y = df['class']
y.head()
# Out:
# 0    Типовой
# 1    Комфорт
# 2    Комфорт
# 3    Комфорт
# 4    Комфорт
# Name: class, dtype: object

# %% [markdown]
# ## Деление выборки и SMOTE

# %% [markdown]
# Разделим выборку случайным образом в соотношении 80/20, где 80% строк выделяется для тренировочной выборки, а 20% - для тестовой.
#
# У нас есть явный дисбаланс классов, поэтому мы обязательно будем использовать кросс-валидацию. Кроме того, выборки может не хватить и случайное ее разделение не очень хорошо подходит, поэтому можно искусственно увеличить ее за счет, например, метода SMOTE.

# %%
y.value_counts()
# Out:
# class
# Комфорт    5038
# Типовой    2581
# Бизнес      785
# Элитный     212
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize = (5, 5))
colors = ['#FFB482', '#A1C9F4', '#8DE5A1', '#FF9F9B']
ax.pie(list(y.value_counts()), labels=y.value_counts().index, colors=colors, autopct='%1.1f%%')
ax.set(title = 'Диаграмма процентного соотношения всех классов')
plt.show()

# %%
smote = SMOTE(sampling_strategy='auto', random_state=42, k_neighbors=5)
X_smote, y_smote = smote.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_smote, y_smote, test_size = 0.2, stratify = y_smote, random_state = 42)
X_train.shape, X_test.shape
# Out:
# ((16121, 5), (4031, 5))

# %%
p = list(np.unique(y_train, return_counts=True))
p.append(np.unique(y_test, return_counts=True)[1])
pd.DataFrame(np.array(p).T, columns = ['class', 'train', 'test'])
# Out:
#      class train  test
# 0   Бизнес  4030  1008
# 1  Комфорт  4031  1007
# 2  Типовой  4030  1008
# 3  Элитный  4030  1008

# %%
y_smote.value_counts()
# Out:
# class
# Типовой    5038
# Комфорт    5038
# Бизнес     5038
# Элитный    5038
# Name: count, dtype: int64

# %% [markdown]
# Проскалируем данные

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
X_train
# Out:
# array([[0.23363134, 0.32653061, 0.03894797, 0.66666667, 0.3507047 ],
#        [0.14964933, 0.47933118, 0.13264501, 0.77777778, 0.32312696],
#        [0.0840435 , 0.08163265, 0.11776576, 0.22222222, 0.        ],
#        ...,
#        [0.09090645, 0.30204082, 0.40333135, 0.        , 0.53366641],
#        [0.15676011, 0.33449155, 0.15160296, 0.77777778, 0.17039388],
#        [0.05787682, 0.30204082, 0.10764634, 0.77777778, 0.17732244]])

# %%
X_test
# Out:
# array([[0.12276824, 0.24489796, 0.12985778, 0.55555556, 0.        ],
#        [0.14362841, 0.21005823, 0.22965465, 0.66666667, 0.2127184 ],
#        [0.14173618, 0.13061224, 0.06760061, 0.44444444, 0.40232265],
#        ...,
#        [0.13055332, 0.24489796, 0.06962425, 0.33333333, 0.57312085],
#        [0.14450523, 0.21607684, 0.17083819, 0.66666667, 0.19319023],
#        [0.04042024, 0.24489796, 0.12704353, 0.        , 0.26735336]])

# %% [markdown]
# ## Выбор модели

# %% [markdown]
# Проведем сравнение нескольких моделей с помощью кросс-валидации. Для сравнения будем использовать следующие модели:
#
#
# 1. Модель логистической регрессии (LogisticRegression);
# 2. Метод опорных векторов без ядра (SVC(kernel = "linear"));
# 3. Метод опорных векторов с гауссовским ядром (SVC(kernel = "rbf"));
# 4. Гауссовский Наивный Байес (GaussianNB);
# 5. Категориальный Наивный Байес (CategoricalNB);
# 6. Случайный лес (RandomForestClassifier);
# 7. Градиентный бустинг (GradientBoostingClassifier);
# 8. CatBoost (CatBoostClassifier).

# %%
classifiers = {"Logistic Regression": LogisticRegression(max_iter = 2000),
               "Linear SVM": SVC(kernel = "linear"),
               "RBF SVM": SVC(kernel = "rbf"),
               "Gaussian Naive Bayes": GaussianNB(),
               "Categorical Naive Bayes": CategoricalNB(),
               "Random Forest": RandomForestClassifier(),
               "Gradient Boosting": GradientBoostingClassifier(),
               'CatBoost': CatBoostClassifier()}

# %%
scores = {}

for name, clf in classifiers.items():
    cv_results = cross_validate(clf, X_train, y_train, cv=5, scoring='f1_macro', return_train_score = True)

    scores[name] = [cv_results['test_score'].mean(), cv_results['train_score'].mean(), cv_results['fit_time'].mean()]
# Out:
# Streaming output truncated to the last 5000 lines.
# 4:	learn: 1.0721690	total: 96ms	remaining: 19.1s
# 5:	learn: 1.0350422	total: 105ms	remaining: 17.4s
# 6:	learn: 1.0024979	total: 114ms	remaining: 16.1s
# 7:	learn: 0.9737603	total: 122ms	remaining: 15.1s
# 8:	learn: 0.9475832	total: 130ms	remaining: 14.3s
# 9:	learn: 0.9253250	total: 139ms	remaining: 13.7s
# 10:	learn: 0.9008006	total: 148ms	remaining: 13.3s
# 11:	learn: 0.8825023	total: 156ms	remaining: 12.8s
# 12:	learn: 0.8664634	total: 164ms	remaining: 12.5s
# 13:	learn: 0.8520814	total: 173ms	remaining: 12.2s
# 14:	learn: 0.8398998	total: 181ms	remaining: 11.9s
# 15:	learn: 0.8226702	total: 189ms	remaining: 11.6s
# 16:	learn: 0.8112956	total: 202ms	remaining: 11.7s
# 17:	learn: 0.7995093	total: 210ms	remaining: 11.5s
# 18:	learn: 0.7897746	total: 219ms	remaining: 11.3s
# 19:	learn: 0.7811934	total: 227ms	remaining: 11.1s
# 20:	learn: 0.7728849	total: 238ms	remaining: 11.1s
# 21:	learn: 0.7653113	total: 248ms	remaining: 11s
# 22:	learn: 0.7575328	total: 258ms	remaining: 11s
# 23:	learn: 0.7501341	total: 267ms	remaining: 10.9s
# 24:	learn: 0.7411434	total: 276ms	remaining: 10.8s
# 25:	learn: 0.7351635	total: 284ms	remaining: 10.7s
# 26:	learn: 0.7294590	total: 293ms	remaining: 10.5s
# 27:	learn: 0.7223346	total: 302ms	remaining: 10.5s
# 28:	learn: 0.7168233	total: 316ms	remaining: 10.6s
# 29:	learn: 0.7125706	total: 325ms	remaining: 10.5s
# 30:	learn: 0.7055730	total: 334ms	remaining: 10.4s
# 31:	learn: 0.7004316	total: 342ms	remaining: 10.3s
# 32:	learn: 0.6948695	total: 350ms	remaining: 10.3s
# 33:	learn: 0.6894168	total: 359ms	remaining: 10.2s
# 34:	learn: 0.6851623	total: 368ms	remaining: 10.1s
# 35:	learn: 0.6811148	total: 376ms	remaining: 10.1s
# 36:	learn: 0.6769108	total: 384ms	remaining: 9.99s
# 37:	learn: 0.6732580	total: 392ms	remaining: 9.94s
# 38:	learn: 0.6679277	total: 405ms	remaining: 9.99s
# 39:	learn: 0.6643376	total: 414ms	remaining: 9.95s
# 40:	learn: 0.6621577	total: 423ms	remaining: 9.89s
# 41:	learn: 0.6592584	total: 432ms	remaining: 9.84s
# 42:	learn: 0.6565305	total: 440ms	remaining: 9.79s
# 43:	learn: 0.6538524	total: 448ms	remaining: 9.74s
# 44:	learn: 0.6509876	total: 457ms	remaining: 9.7s
# 45:	learn: 0.6481756	total: 466ms	remaining: 9.66s
# 46:	learn: 0.6454566	total: 474ms	remaining: 9.61s
# 47:	learn: 0.6431543	total: 482ms	remaining: 9.56s
# 48:	learn: 0.6409278	total: 490ms	remaining: 9.52s
# 49:	learn: 0.6385210	total: 498ms	remaining: 9.47s
# 50:	learn: 0.6350808	total: 511ms	remaining: 9.51s
# 51:	learn: 0.6334067	total: 529ms	remaining: 9.64s
# 52:	learn: 0.6304533	total: 537ms	remaining: 9.6s
# 53:	learn: 0.6281216	total: 546ms	remaining: 9.56s
# 54:	learn: 0.6264106	total: 554ms	remaining: 9.51s
# 55:	learn: 0.6246182	total: 567ms	remaining: 9.55s
# 56:	learn: 0.6232694	total: 574ms	remaining: 9.5s
# 57:	learn: 0.6215881	total: 582ms	remaining: 9.46s
# 58:	learn: 0.6195426	total: 590ms	remaining: 9.41s
# 59:	learn: 0.6170708	total: 599ms	remaining: 9.38s
# 60:	learn: 0.6143123	total: 611ms	remaining: 9.41s
# 61:	learn: 0.6127865	total: 620ms	remaining: 9.39s
# 62:	learn: 0.6111588	total: 629ms	remaining: 9.36s
# 63:	learn: 0.6095877	total: 637ms	remaining: 9.32s
# 64:	learn: 0.6077265	total: 646ms	remaining: 9.29s
# 65:	learn: 0.6050807	total: 655ms	remaining: 9.26s
# 66:	learn: 0.6034686	total: 663ms	remaining: 9.23s
# 67:	learn: 0.6015224	total: 672ms	remaining: 9.21s
# 68:	learn: 0.5990700	total: 681ms	remaining: 9.18s
# 69:	learn: 0.5973518	total: 689ms	remaining: 9.15s
# 70:	learn: 0.5948530	total: 698ms	remaining: 9.13s
# 71:	learn: 0.5924690	total: 706ms	remaining: 9.1s
# 72:	learn: 0.5902308	total: 714ms	remaining: 9.07s
# 73:	learn: 0.5887315	total: 723ms	remaining: 9.04s
# 74:	learn: 0.5878200	total: 731ms	remaining: 9.01s
# 75:	learn: 0.5863187	total: 739ms	remaining: 8.98s
# 76:	learn: 0.5837900	total: 748ms	remaining: 8.96s
# 77:	learn: 0.5820318	total: 756ms	remaining: 8.94s
# 78:	learn: 0.5807674	total: 765ms	remaining: 8.91s
# 79:	learn: 0.5797639	total: 773ms	remaining: 8.89s
# 80:	learn: 0.5781779	total: 782ms	remaining: 8.87s
# 81:	learn: 0.5762512	total: 790ms	remaining: 8.85s
# 82:	learn: 0.5744045	total: 799ms	remaining: 8.82s
# 83:	learn: 0.5717825	total: 809ms	remaining: 8.82s
# 84:	learn: 0.5708734	total: 819ms	remaining: 8.81s
# 85:	learn: 0.5695635	total: 827ms	remaining: 8.79s
# 86:	learn: 0.5675230	total: 836ms	remaining: 8.78s
# 87:	learn: 0.5666025	total: 848ms	remaining: 8.79s
# 88:	learn: 0.5649141	total: 857ms	remaining: 8.77s
# 89:	learn: 0.5638799	total: 866ms	remaining: 8.75s
# 90:	learn: 0.5622599	total: 874ms	remaining: 8.73s
# 91:	learn: 0.5609124	total: 883ms	remaining: 8.71s
# 92:	learn: 0.5591940	total: 892ms	remaining: 8.7s
# 93:	learn: 0.5574501	total: 900ms	remaining: 8.67s
# 94:	learn: 0.5563121	total: 909ms	remaining: 8.66s
# 95:	learn: 0.5548620	total: 918ms	remaining: 8.64s
# 96:	learn: 0.5533283	total: 927ms	remaining: 8.63s
# 97:	learn: 0.5526981	total: 935ms	remaining: 8.6s
# 98:	learn: 0.5513414	total: 945ms	remaining: 8.6s
# 99:	learn: 0.5498565	total: 953ms	remaining: 8.58s
# 100:	learn: 0.5486880	total: 961ms	remaining: 8.56s
# 101:	learn: 0.5463969	total: 970ms	remaining: 8.54s
# 102:	learn: 0.5458522	total: 978ms	remaining: 8.52s
# 103:	learn: 0.5440915	total: 987ms	remaining: 8.5s
# 104:	learn: 0.5426417	total: 995ms	remaining: 8.48s
# 105:	learn: 0.5404013	total: 1s	remaining: 8.46s
# 106:	learn: 0.5385689	total: 1.01s	remaining: 8.47s
# 107:	learn: 0.5374138	total: 1.02s	remaining: 8.46s
# 108:	learn: 0.5356806	total: 1.03s	remaining: 8.46s
# 109:	learn: 0.5351523	total: 1.04s	remaining: 8.44s
# 110:	learn: 0.5330004	total: 1.05s	remaining: 8.43s
# 111:	learn: 0.5314099	total: 1.06s	remaining: 8.41s
# 112:	learn: 0.5307337	total: 1.07s	remaining: 8.39s
# 113:	learn: 0.5295240	total: 1.08s	remaining: 8.38s
# 114:	learn: 0.5279784	total: 1.09s	remaining: 8.36s
# 115:	learn: 0.5272115	total: 1.09s	remaining: 8.34s
# 116:	learn: 0.5260317	total: 1.1s	remaining: 8.32s
# 117:	learn: 0.5254766	total: 1.11s	remaining: 8.3s
# 118:	learn: 0.5241906	total: 1.12s	remaining: 8.31s
# 119:	learn: 0.5226254	total: 1.13s	remaining: 8.3s
# 120:	learn: 0.5218608	total: 1.14s	remaining: 8.28s
# 121:	learn: 0.5213377	total: 1.15s	remaining: 8.26s
# 122:	learn: 0.5197436	total: 1.16s	remaining: 8.24s
# 123:	learn: 0.5183150	total: 1.17s	remaining: 8.23s
# 124:	learn: 0.5174045	total: 1.17s	remaining: 8.21s
# 125:	learn: 0.5165153	total: 1.18s	remaining: 8.2s
# 126:	learn: 0.5156624	total: 1.19s	remaining: 8.18s
# 127:	learn: 0.5137989	total: 1.2s	remaining: 8.17s
# 128:	learn: 0.5122554	total: 1.21s	remaining: 8.17s
# 129:	learn: 0.5111272	total: 1.22s	remaining: 8.19s
# 130:	learn: 0.5100369	total: 1.24s	remaining: 8.2s
# 131:	learn: 0.5092219	total: 1.24s	remaining: 8.18s
# 132:	learn: 0.5081841	total: 1.25s	remaining: 8.16s
# 133:	learn: 0.5068461	total: 1.26s	remaining: 8.15s
# 134:	learn: 0.5059038	total: 1.27s	remaining: 8.13s
# 135:	learn: 0.5047379	total: 1.28s	remaining: 8.12s
# 136:	learn: 0.5035119	total: 1.29s	remaining: 8.11s
# 137:	learn: 0.5021382	total: 1.3s	remaining: 8.1s
# 138:	learn: 0.5011536	total: 1.3s	remaining: 8.08s
# 139:	learn: 0.4999842	total: 1.31s	remaining: 8.07s
# 140:	learn: 0.4992612	total: 1.32s	remaining: 8.05s
# 141:	learn: 0.4984976	total: 1.33s	remaining: 8.03s
# 142:	learn: 0.4973620	total: 1.34s	remaining: 8.02s
# 143:	learn: 0.4962939	total: 1.35s	remaining: 8s
# 144:	learn: 0.4953286	total: 1.35s	remaining: 7.99s
# 145:	learn: 0.4937470	total: 1.36s	remaining: 7.98s
# 146:	learn: 0.4930294	total: 1.37s	remaining: 7.96s
# 147:	learn: 0.4922088	total: 1.38s	remaining: 7.95s
# 148:	learn: 0.4904351	total: 1.39s	remaining: 7.94s
# 149:	learn: 0.4891884	total: 1.4s	remaining: 7.92s
# 150:	learn: 0.4888587	total: 1.41s	remaining: 7.9s
# 151:	learn: 0.4881023	total: 1.41s	remaining: 7.89s
# 152:	learn: 0.4871202	total: 1.43s	remaining: 7.9s
# 153:	learn: 0.4861018	total: 1.44s	remaining: 7.88s
# 154:	learn: 0.4849490	total: 1.45s	remaining: 7.92s
# 155:	learn: 0.4843129	total: 1.46s	remaining: 7.91s
# 156:	learn: 0.4829867	total: 1.47s	remaining: 7.89s
# 157:	learn: 0.4818436	total: 1.48s	remaining: 7.88s
# 158:	learn: 0.4813567	total: 1.49s	remaining: 7.87s
# 159:	learn: 0.4809592	total: 1.5s	remaining: 7.85s
# 160:	learn: 0.4799496	total: 1.51s	remaining: 7.86s
# 161:	learn: 0.4792009	total: 1.53s	remaining: 7.89s
# 162:	learn: 0.4782716	total: 1.53s	remaining: 7.88s
# 163:	learn: 0.4774885	total: 1.54s	remaining: 7.87s
# 164:	learn: 0.4767516	total: 1.55s	remaining: 7.85s
# 165:	learn: 0.4752375	total: 1.56s	remaining: 7.84s
# 166:	learn: 0.4745940	total: 1.57s	remaining: 7.82s
# 167:	learn: 0.4736816	total: 1.58s	remaining: 7.81s
# 168:	learn: 0.4731331	total: 1.58s	remaining: 7.8s
# 169:	learn: 0.4722879	total: 1.59s	remaining: 7.78s
# 170:	learn: 0.4713197	total: 1.6s	remaining: 7.77s
# 171:	learn: 0.4708751	total: 1.61s	remaining: 7.76s
# 172:	learn: 0.4704671	total: 1.63s	remaining: 7.79s
# 173:	learn: 0.4700201	total: 1.64s	remaining: 7.77s
# 174:	learn: 0.4692722	total: 1.65s	remaining: 7.76s
# 175:	learn: 0.4684412	total: 1.66s	remaining: 7.75s
# 176:	learn: 0.4678194	total: 1.66s	remaining: 7.74s
# 177:	learn: 0.4666218	total: 1.67s	remaining: 7.72s
# 178:	learn: 0.4657622	total: 1.68s	remaining: 7.71s
# 179:	learn: 0.4652698	total: 1.69s	remaining: 7.7s
# 180:	learn: 0.4645708	total: 1.7s	remaining: 7.68s
# 181:	learn: 0.4634065	total: 1.71s	remaining: 7.67s
# 182:	learn: 0.4628054	total: 1.72s	remaining: 7.66s
# 183:	learn: 0.4625722	total: 1.72s	remaining: 7.64s
# 184:	learn: 0.4620196	total: 1.73s	remaining: 7.63s
# 185:	learn: 0.4610406	total: 1.74s	remaining: 7.62s
# 186:	learn: 0.4602674	total: 1.75s	remaining: 7.61s
# 187:	learn: 0.4595287	total: 1.76s	remaining: 7.6s
# 188:	learn: 0.4587848	total: 1.77s	remaining: 7.6s
# 189:	learn: 0.4580433	total: 1.78s	remaining: 7.6s
# 190:	learn: 0.4574355	total: 1.79s	remaining: 7.59s
# 191:	learn: 0.4569108	total: 1.8s	remaining: 7.57s
# 192:	learn: 0.4563221	total: 1.81s	remaining: 7.56s
# 193:	learn: 0.4557251	total: 1.82s	remaining: 7.55s
# 194:	learn: 0.4547539	total: 1.83s	remaining: 7.55s
# 195:	learn: 0.4539637	total: 1.84s	remaining: 7.55s
# 196:	learn: 0.4533586	total: 1.85s	remaining: 7.54s
# 197:	learn: 0.4523323	total: 1.86s	remaining: 7.53s
# 198:	learn: 0.4512349	total: 1.87s	remaining: 7.52s
# 199:	learn: 0.4502955	total: 1.88s	remaining: 7.51s
# 200:	learn: 0.4495391	total: 1.89s	remaining: 7.49s
# 201:	learn: 0.4486741	total: 1.89s	remaining: 7.48s
# 202:	learn: 0.4477735	total: 1.9s	remaining: 7.47s
# 203:	learn: 0.4473303	total: 1.91s	remaining: 7.46s
# 204:	learn: 0.4466605	total: 1.92s	remaining: 7.45s
# 205:	learn: 0.4458443	total: 1.93s	remaining: 7.43s
# 206:	learn: 0.4446310	total: 1.94s	remaining: 7.42s
# 207:	learn: 0.4439290	total: 1.95s	remaining: 7.41s
# 208:	learn: 0.4430424	total: 1.96s	remaining: 7.4s
# 209:	learn: 0.4425801	total: 1.96s	remaining: 7.39s
# 210:	learn: 0.4415379	total: 1.97s	remaining: 7.38s
# 211:	learn: 0.4404686	total: 1.98s	remaining: 7.36s
# 212:	learn: 0.4393798	total: 1.99s	remaining: 7.35s
# 213:	learn: 0.4387481	total: 2s	remaining: 7.34s
# 214:	learn: 0.4379382	total: 2.01s	remaining: 7.33s
# 215:	learn: 0.4372807	total: 2.02s	remaining: 7.32s
# 216:	learn: 0.4366283	total: 2.03s	remaining: 7.31s
# 217:	learn: 0.4362846	total: 2.04s	remaining: 7.31s
# 218:	learn: 0.4358789	total: 2.05s	remaining: 7.3s
# 219:	learn: 0.4352810	total: 2.05s	remaining: 7.28s
# 220:	learn: 0.4344588	total: 2.06s	remaining: 7.27s
# 221:	learn: 0.4337856	total: 2.07s	remaining: 7.26s
# 222:	learn: 0.4331505	total: 2.08s	remaining: 7.25s
# 223:	learn: 0.4328292	total: 2.09s	remaining: 7.23s
# 224:	learn: 0.4325156	total: 2.1s	remaining: 7.22s
# 225:	learn: 0.4319252	total: 2.11s	remaining: 7.22s
# 226:	learn: 0.4314979	total: 2.12s	remaining: 7.21s
# 227:	learn: 0.4308746	total: 2.12s	remaining: 7.19s
# 228:	learn: 0.4299230	total: 2.13s	remaining: 7.18s
# 229:	learn: 0.4289978	total: 2.14s	remaining: 7.17s
# 230:	learn: 0.4287217	total: 2.15s	remaining: 7.16s
# 231:	learn: 0.4277380	total: 2.16s	remaining: 7.15s
# 232:	learn: 0.4269485	total: 2.17s	remaining: 7.14s
# 233:	learn: 0.4266166	total: 2.18s	remaining: 7.12s
# 234:	learn: 0.4262340	total: 2.19s	remaining: 7.12s
# 235:	learn: 0.4254157	total: 2.2s	remaining: 7.11s
# 236:	learn: 0.4245644	total: 2.21s	remaining: 7.1s
# 237:	learn: 0.4243114	total: 2.21s	remaining: 7.09s
# 238:	learn: 0.4239455	total: 2.22s	remaining: 7.08s
# 239:	learn: 0.4232884	total: 2.23s	remaining: 7.06s
# 240:	learn: 0.4227096	total: 2.24s	remaining: 7.06s
# 241:	learn: 0.4223684	total: 2.25s	remaining: 7.05s
# 242:	learn: 0.4217612	total: 2.26s	remaining: 7.04s
# 243:	learn: 0.4212088	total: 2.27s	remaining: 7.03s
# 244:	learn: 0.4200521	total: 2.28s	remaining: 7.01s
# 245:	learn: 0.4196305	total: 2.29s	remaining: 7s
# 246:	learn: 0.4189498	total: 2.29s	remaining: 6.99s
# 247:	learn: 0.4184374	total: 2.3s	remaining: 6.98s
# 248:	learn: 0.4181004	total: 2.31s	remaining: 6.97s
# 249:	learn: 0.4173639	total: 2.32s	remaining: 6.96s
# 250:	learn: 0.4167615	total: 2.33s	remaining: 6.94s
# 251:	learn: 0.4159047	total: 2.33s	remaining: 6.93s
# 252:	learn: 0.4153630	total: 2.34s	remaining: 6.92s
# 253:	learn: 0.4150096	total: 2.35s	remaining: 6.91s
# 254:	learn: 0.4142986	total: 2.36s	remaining: 6.9s
# 255:	learn: 0.4136705	total: 2.37s	remaining: 6.89s
# 256:	learn: 0.4133614	total: 2.38s	remaining: 6.89s
# 257:	learn: 0.4128062	total: 2.39s	remaining: 6.88s
# 258:	learn: 0.4125210	total: 2.4s	remaining: 6.87s
# 259:	learn: 0.4120348	total: 2.41s	remaining: 6.86s
# 260:	learn: 0.4113633	total: 2.42s	remaining: 6.85s
# 261:	learn: 0.4106790	total: 2.43s	remaining: 6.84s
# 262:	learn: 0.4102135	total: 2.44s	remaining: 6.83s
# 263:	learn: 0.4096695	total: 2.45s	remaining: 6.83s
# 264:	learn: 0.4089189	total: 2.46s	remaining: 6.82s
# 265:	learn: 0.4081095	total: 2.47s	remaining: 6.81s
# 266:	learn: 0.4078606	total: 2.47s	remaining: 6.79s
# 267:	learn: 0.4073795	total: 2.48s	remaining: 6.78s
# 268:	learn: 0.4068230	total: 2.49s	remaining: 6.77s
# 269:	learn: 0.4062561	total: 2.5s	remaining: 6.77s
# 270:	learn: 0.4060716	total: 2.52s	remaining: 6.78s
# 271:	learn: 0.4058367	total: 2.53s	remaining: 6.77s
# 272:	learn: 0.4051539	total: 2.54s	remaining: 6.76s
# 273:	learn: 0.4044722	total: 2.55s	remaining: 6.75s
# 274:	learn: 0.4039561	total: 2.56s	remaining: 6.74s
# 275:	learn: 0.4035076	total: 2.56s	remaining: 6.72s
# 276:	learn: 0.4027555	total: 2.57s	remaining: 6.71s
# 277:	learn: 0.4023872	total: 2.58s	remaining: 6.7s
# 278:	learn: 0.4018232	total: 2.59s	remaining: 6.69s
# 279:	learn: 0.4008920	total: 2.6s	remaining: 6.68s
# 280:	learn: 0.4004999	total: 2.6s	remaining: 6.67s
# 281:	learn: 0.3999626	total: 2.61s	remaining: 6.66s
# 282:	learn: 0.3995087	total: 2.62s	remaining: 6.64s
# 283:	learn: 0.3988687	total: 2.63s	remaining: 6.63s
# 284:	learn: 0.3985227	total: 2.64s	remaining: 6.62s
# 285:	learn: 0.3979986	total: 2.65s	remaining: 6.62s
# 286:	learn: 0.3978123	total: 2.66s	remaining: 6.62s
# 287:	learn: 0.3973015	total: 2.67s	remaining: 6.61s
# 288:	learn: 0.3965375	total: 2.68s	remaining: 6.6s
# 289:	learn: 0.3959754	total: 2.69s	remaining: 6.59s
# 290:	learn: 0.3954172	total: 2.7s	remaining: 6.58s
# 291:	learn: 0.3951179	total: 2.71s	remaining: 6.56s
# 292:	learn: 0.3945225	total: 2.71s	remaining: 6.55s
# 293:	learn: 0.3939526	total: 2.72s	remaining: 6.54s
# 294:	learn: 0.3933281	total: 2.73s	remaining: 6.53s
# 295:	learn: 0.3930480	total: 2.74s	remaining: 6.52s
# 296:	learn: 0.3927649	total: 2.75s	remaining: 6.51s
# 297:	learn: 0.3925293	total: 2.76s	remaining: 6.5s
# 298:	learn: 0.3920448	total: 2.77s	remaining: 6.49s
# 299:	learn: 0.3915563	total: 2.77s	remaining: 6.47s
# 300:	learn: 0.3911517	total: 2.78s	remaining: 6.46s
# 301:	learn: 0.3905648	total: 2.79s	remaining: 6.45s
# 302:	learn: 0.3903272	total: 2.8s	remaining: 6.44s
# 303:	learn: 0.3898242	total: 2.81s	remaining: 6.43s
# 304:	learn: 0.3895268	total: 2.81s	remaining: 6.42s
# 305:	learn: 0.3890525	total: 2.82s	remaining: 6.41s
# 306:	learn: 0.3887138	total: 2.83s	remaining: 6.39s
# 307:	learn: 0.3884217	total: 2.84s	remaining: 6.38s
# 308:	learn: 0.3877155	total: 2.85s	remaining: 6.38s
# 309:	learn: 0.3869795	total: 2.86s	remaining: 6.37s
# 310:	learn: 0.3865959	total: 2.87s	remaining: 6.36s
# 311:	learn: 0.3859545	total: 2.88s	remaining: 6.35s
# 312:	learn: 0.3853262	total: 2.89s	remaining: 6.34s
# 313:	learn: 0.3847434	total: 2.9s	remaining: 6.33s
# 314:	learn: 0.3842307	total: 2.91s	remaining: 6.32s
# 315:	learn: 0.3839354	total: 2.91s	remaining: 6.31s
# 316:	learn: 0.3834356	total: 2.92s	remaining: 6.3s
# 317:	learn: 0.3828636	total: 2.93s	remaining: 6.29s
# 318:	learn: 0.3825348	total: 2.94s	remaining: 6.28s
# 319:	learn: 0.3817010	total: 2.95s	remaining: 6.28s
# 320:	learn: 0.3812634	total: 2.96s	remaining: 6.27s
# 321:	learn: 0.3808035	total: 2.97s	remaining: 6.26s
# 322:	learn: 0.3804607	total: 2.98s	remaining: 6.25s
# 323:	learn: 0.3798326	total: 2.99s	remaining: 6.24s
# 324:	learn: 0.3792805	total: 3s	remaining: 6.24s
# 325:	learn: 0.3789810	total: 3.01s	remaining: 6.22s
# 326:	learn: 0.3781085	total: 3.02s	remaining: 6.22s
# 327:	learn: 0.3777656	total: 3.03s	remaining: 6.21s
# 328:	learn: 0.3771488	total: 3.04s	remaining: 6.2s
# 329:	learn: 0.3766371	total: 3.05s	remaining: 6.18s
# 330:	learn: 0.3762834	total: 3.06s	remaining: 6.18s
# 331:	learn: 0.3757691	total: 3.07s	remaining: 6.17s
# 332:	learn: 0.3752842	total: 3.08s	remaining: 6.16s
# 333:	learn: 0.3744937	total: 3.09s	remaining: 6.16s
# 334:	learn: 0.3740128	total: 3.1s	remaining: 6.15s
# 335:	learn: 0.3737028	total: 3.11s	remaining: 6.14s
# 336:	learn: 0.3729571	total: 3.12s	remaining: 6.13s
# 337:	learn: 0.3724556	total: 3.13s	remaining: 6.12s
# 338:	learn: 0.3719757	total: 3.13s	remaining: 6.11s
# 339:	learn: 0.3716769	total: 3.14s	remaining: 6.1s
# 340:	learn: 0.3713139	total: 3.15s	remaining: 6.09s
# 341:	learn: 0.3706122	total: 3.16s	remaining: 6.08s
# 342:	learn: 0.3701756	total: 3.17s	remaining: 6.07s
# 343:	learn: 0.3697124	total: 3.18s	remaining: 6.07s
# 344:	learn: 0.3693603	total: 3.19s	remaining: 6.06s
# 345:	learn: 0.3691346	total: 3.2s	remaining: 6.04s
# 346:	learn: 0.3685107	total: 3.21s	remaining: 6.04s
# 347:	learn: 0.3680884	total: 3.22s	remaining: 6.03s
# 348:	learn: 0.3678881	total: 3.23s	remaining: 6.02s
# 349:	learn: 0.3673167	total: 3.24s	remaining: 6.01s
# 350:	learn: 0.3670914	total: 3.25s	remaining: 6s
# 351:	learn: 0.3667664	total: 3.26s	remaining: 6s
# 352:	learn: 0.3660708	total: 3.27s	remaining: 5.99s
# 353:	learn: 0.3658249	total: 3.27s	remaining: 5.98s
# 354:	learn: 0.3656844	total: 3.28s	remaining: 5.96s
# 355:	learn: 0.3654388	total: 3.29s	remaining: 5.96s
# 356:	learn: 0.3650164	total: 3.3s	remaining: 5.94s
# 357:	learn: 0.3643913	total: 3.31s	remaining: 5.93s
# 358:	learn: 0.3637608	total: 3.32s	remaining: 5.92s
# 359:	learn: 0.3633340	total: 3.33s	remaining: 5.91s
# 360:	learn: 0.3631699	total: 3.33s	remaining: 5.9s
# 361:	learn: 0.3628856	total: 3.34s	remaining: 5.89s
# 362:	learn: 0.3626964	total: 3.35s	remaining: 5.88s
# 363:	learn: 0.3621533	total: 3.36s	remaining: 5.87s
# 364:	learn: 0.3617271	total: 3.37s	remaining: 5.86s
# 365:	learn: 0.3613234	total: 3.38s	remaining: 5.85s
# 366:	learn: 0.3610843	total: 3.38s	remaining: 5.84s
# 367:	learn: 0.3607627	total: 3.39s	remaining: 5.83s
# 368:	learn: 0.3604104	total: 3.4s	remaining: 5.82s
# 369:	learn: 0.3599660	total: 3.42s	remaining: 5.82s
# 370:	learn: 0.3595193	total: 3.42s	remaining: 5.81s
# 371:	learn: 0.3591103	total: 3.43s	remaining: 5.8s
# 372:	learn: 0.3587579	total: 3.44s	remaining: 5.79s
# 373:	learn: 0.3584504	total: 3.45s	remaining: 5.77s
# 374:	learn: 0.3581914	total: 3.46s	remaining: 5.77s
# 375:	learn: 0.3575845	total: 3.47s	remaining: 5.76s
# 376:	learn: 0.3571600	total: 3.48s	remaining: 5.75s
# 377:	learn: 0.3567203	total: 3.49s	remaining: 5.74s
# 378:	learn: 0.3564225	total: 3.5s	remaining: 5.74s
# 379:	learn: 0.3559766	total: 3.52s	remaining: 5.74s
# 380:	learn: 0.3556157	total: 3.53s	remaining: 5.73s
# 381:	learn: 0.3551273	total: 3.54s	remaining: 5.72s
# 382:	learn: 0.3546627	total: 3.55s	remaining: 5.72s
# 383:	learn: 0.3543005	total: 3.56s	remaining: 5.71s
# 384:	learn: 0.3540597	total: 3.57s	remaining: 5.7s
# 385:	learn: 0.3537437	total: 3.58s	remaining: 5.69s
# 386:	learn: 0.3534361	total: 3.58s	remaining: 5.68s
# 387:	learn: 0.3530661	total: 3.59s	remaining: 5.67s
# 388:	learn: 0.3527265	total: 3.6s	remaining: 5.66s
# 389:	learn: 0.3522711	total: 3.61s	remaining: 5.65s
# 390:	learn: 0.3520958	total: 3.62s	remaining: 5.64s
# 391:	learn: 0.3517902	total: 3.63s	remaining: 5.63s
# 392:	learn: 0.3516097	total: 3.64s	remaining: 5.62s
# 393:	learn: 0.3511384	total: 3.65s	remaining: 5.61s
# 394:	learn: 0.3506608	total: 3.66s	remaining: 5.6s
# 395:	learn: 0.3503132	total: 3.67s	remaining: 5.6s
# 396:	learn: 0.3498668	total: 3.68s	remaining: 5.59s
# 397:	learn: 0.3492341	total: 3.69s	remaining: 5.58s
# 398:	learn: 0.3490188	total: 3.7s	remaining: 5.57s
# 399:	learn: 0.3485836	total: 3.71s	remaining: 5.56s
# 400:	learn: 0.3482281	total: 3.72s	remaining: 5.55s
# 401:	learn: 0.3480931	total: 3.73s	remaining: 5.54s
# 402:	learn: 0.3479000	total: 3.73s	remaining: 5.53s
# 403:	learn: 0.3476958	total: 3.74s	remaining: 5.52s
# 404:	learn: 0.3472398	total: 3.75s	remaining: 5.51s
# 405:	learn: 0.3469972	total: 3.76s	remaining: 5.5s
# 406:	learn: 0.3464250	total: 3.77s	remaining: 5.49s
# 407:	learn: 0.3462366	total: 3.78s	remaining: 5.48s
# 408:	learn: 0.3457350	total: 3.79s	remaining: 5.47s
# 409:	learn: 0.3454528	total: 3.8s	remaining: 5.46s
# 410:	learn: 0.3451011	total: 3.81s	remaining: 5.45s
# 411:	learn: 0.3444964	total: 3.81s	remaining: 5.45s
# 412:	learn: 0.3442931	total: 3.82s	remaining: 5.43s
# 413:	learn: 0.3436311	total: 3.83s	remaining: 5.43s
# 414:	learn: 0.3432253	total: 3.84s	remaining: 5.42s
# 415:	learn: 0.3430313	total: 3.85s	remaining: 5.41s
# 416:	learn: 0.3427180	total: 3.86s	remaining: 5.4s
# 417:	learn: 0.3422144	total: 3.88s	remaining: 5.4s
# 418:	learn: 0.3416664	total: 3.88s	remaining: 5.39s
# 419:	learn: 0.3412587	total: 3.89s	remaining: 5.38s
# 420:	learn: 0.3407845	total: 3.9s	remaining: 5.37s
# 421:	learn: 0.3404430	total: 3.91s	remaining: 5.36s
# 422:	learn: 0.3401119	total: 3.92s	remaining: 5.35s
# 423:	learn: 0.3398873	total: 3.93s	remaining: 5.33s
# 424:	learn: 0.3396373	total: 3.94s	remaining: 5.33s
# 425:	learn: 0.3393772	total: 3.94s	remaining: 5.32s
# 426:	learn: 0.3390844	total: 3.95s	remaining: 5.3s
# 427:	learn: 0.3386789	total: 3.96s	remaining: 5.29s
# 428:	learn: 0.3383484	total: 3.97s	remaining: 5.29s
# 429:	learn: 0.3378943	total: 3.98s	remaining: 5.28s
# 430:	learn: 0.3376876	total: 3.99s	remaining: 5.27s
# 431:	learn: 0.3372577	total: 4s	remaining: 5.26s
# 432:	learn: 0.3370817	total: 4.01s	remaining: 5.25s
# 433:	learn: 0.3368553	total: 4.01s	remaining: 5.24s
# 434:	learn: 0.3364674	total: 4.02s	remaining: 5.22s
# 435:	learn: 0.3361772	total: 4.03s	remaining: 5.21s
# 436:	learn: 0.3357732	total: 4.04s	remaining: 5.2s
# 437:	learn: 0.3353160	total: 4.05s	remaining: 5.19s
# 438:	learn: 0.3350161	total: 4.06s	remaining: 5.18s
# 439:	learn: 0.3346745	total: 4.07s	remaining: 5.17s
# 440:	learn: 0.3343646	total: 4.08s	remaining: 5.17s
# 441:	learn: 0.3341318	total: 4.09s	remaining: 5.16s
# 442:	learn: 0.3338944	total: 4.1s	remaining: 5.16s
# 443:	learn: 0.3335596	total: 4.12s	remaining: 5.16s
# 444:	learn: 0.3331375	total: 4.14s	remaining: 5.16s
# 445:	learn: 0.3328670	total: 4.15s	remaining: 5.16s
# 446:	learn: 0.3325612	total: 4.16s	remaining: 5.15s
# 447:	learn: 0.3323587	total: 4.18s	remaining: 5.15s
# 448:	learn: 0.3321794	total: 4.19s	remaining: 5.14s
# 449:	learn: 0.3318707	total: 4.2s	remaining: 5.13s
# 450:	learn: 0.3317068	total: 4.21s	remaining: 5.12s
# 451:	learn: 0.3313866	total: 4.23s	remaining: 5.13s
# 452:	learn: 0.3309965	total: 4.24s	remaining: 5.12s
# 453:	learn: 0.3307981	total: 4.26s	remaining: 5.13s
# 454:	learn: 0.3304958	total: 4.29s	remaining: 5.13s
# 455:	learn: 0.3300004	total: 4.3s	remaining: 5.13s
# 456:	learn: 0.3296801	total: 4.32s	remaining: 5.14s
# 457:	learn: 0.3294598	total: 4.34s	remaining: 5.13s
# 458:	learn: 0.3292289	total: 4.36s	remaining: 5.14s
# 459:	learn: 0.3289450	total: 4.38s	remaining: 5.14s
# 460:	learn: 0.3286527	total: 4.4s	remaining: 5.15s
# 461:	learn: 0.3284247	total: 4.42s	remaining: 5.15s
# 462:	learn: 0.3282561	total: 4.43s	remaining: 5.14s
# 463:	learn: 0.3279704	total: 4.45s	remaining: 5.14s
# 464:	learn: 0.3275064	total: 4.47s	remaining: 5.15s
# 465:	learn: 0.3268986	total: 4.5s	remaining: 5.16s
# 466:	learn: 0.3265612	total: 4.52s	remaining: 5.16s
# 467:	learn: 0.3262945	total: 4.54s	remaining: 5.17s
# 468:	learn: 0.3259041	total: 4.56s	remaining: 5.17s
# 469:	learn: 0.3255074	total: 4.58s	remaining: 5.16s
# 470:	learn: 0.3252860	total: 4.59s	remaining: 5.16s
# 471:	learn: 0.3250254	total: 4.6s	remaining: 5.15s
# 472:	learn: 0.3248700	total: 4.62s	remaining: 5.14s
# 473:	learn: 0.3246955	total: 4.63s	remaining: 5.14s
# 474:	learn: 0.3244332	total: 4.65s	remaining: 5.14s
# 475:	learn: 0.3242903	total: 4.67s	remaining: 5.15s
# 476:	learn: 0.3239806	total: 4.69s	remaining: 5.14s
# 477:	learn: 0.3237320	total: 4.72s	remaining: 5.15s
# 478:	learn: 0.3235114	total: 4.74s	remaining: 5.15s
# 479:	learn: 0.3231220	total: 4.76s	remaining: 5.16s
# 480:	learn: 0.3229719	total: 4.78s	remaining: 5.16s
# 481:	learn: 0.3228086	total: 4.8s	remaining: 5.16s
# 482:	learn: 0.3225542	total: 4.82s	remaining: 5.16s
# 483:	learn: 0.3222298	total: 4.84s	remaining: 5.16s
# 484:	learn: 0.3218242	total: 4.86s	remaining: 5.16s
# 485:	learn: 0.3216427	total: 4.88s	remaining: 5.16s
# 486:	learn: 0.3213060	total: 4.91s	remaining: 5.17s
# 487:	learn: 0.3210738	total: 4.93s	remaining: 5.17s
# 488:	learn: 0.3207699	total: 4.95s	remaining: 5.18s
# 489:	learn: 0.3204908	total: 4.97s	remaining: 5.17s
# 490:	learn: 0.3201446	total: 4.99s	remaining: 5.17s
# 491:	learn: 0.3198304	total: 5.01s	remaining: 5.17s
# 492:	learn: 0.3196827	total: 5.03s	remaining: 5.17s
# 493:	learn: 0.3194451	total: 5.05s	remaining: 5.18s
# 494:	learn: 0.3192721	total: 5.07s	remaining: 5.18s
# 495:	learn: 0.3188972	total: 5.09s	remaining: 5.18s
# 496:	learn: 0.3187090	total: 5.11s	remaining: 5.17s
# 497:	learn: 0.3185361	total: 5.12s	remaining: 5.16s
# 498:	learn: 0.3182154	total: 5.15s	remaining: 5.17s
# 499:	learn: 0.3179508	total: 5.17s	remaining: 5.17s
# 500:	learn: 0.3175760	total: 5.19s	remaining: 5.17s
# 501:	learn: 0.3174092	total: 5.21s	remaining: 5.17s
# 502:	learn: 0.3169768	total: 5.23s	remaining: 5.17s
# 503:	learn: 0.3166579	total: 5.25s	remaining: 5.17s
# 504:	learn: 0.3164077	total: 5.27s	remaining: 5.16s
# 505:	learn: 0.3162552	total: 5.29s	remaining: 5.16s
# 506:	learn: 0.3160126	total: 5.31s	remaining: 5.16s
# 507:	learn: 0.3157089	total: 5.34s	remaining: 5.17s
# 508:	learn: 0.3154520	total: 5.36s	remaining: 5.17s
# 509:	learn: 0.3150173	total: 5.38s	remaining: 5.17s
# 510:	learn: 0.3147758	total: 5.4s	remaining: 5.16s
# 511:	learn: 0.3143739	total: 5.42s	remaining: 5.16s
# 512:	learn: 0.3141533	total: 5.43s	remaining: 5.16s
# 513:	learn: 0.3139016	total: 5.46s	remaining: 5.16s
# 514:	learn: 0.3136335	total: 5.47s	remaining: 5.16s
# 515:	learn: 0.3133652	total: 5.5s	remaining: 5.16s
# 516:	learn: 0.3129910	total: 5.52s	remaining: 5.16s
# 517:	learn: 0.3123628	total: 5.54s	remaining: 5.16s
# 518:	learn: 0.3121692	total: 5.56s	remaining: 5.15s
# 519:	learn: 0.3118637	total: 5.58s	remaining: 5.16s
# 520:	learn: 0.3116923	total: 5.6s	remaining: 5.15s
# 521:	learn: 0.3114133	total: 5.62s	remaining: 5.15s
# 522:	learn: 0.3110067	total: 5.64s	remaining: 5.14s
# 523:	learn: 0.3107352	total: 5.67s	remaining: 5.15s
# 524:	learn: 0.3103645	total: 5.68s	remaining: 5.14s
# 525:	learn: 0.3102213	total: 5.7s	remaining: 5.14s
# 526:	learn: 0.3099899	total: 5.72s	remaining: 5.13s
# 527:	learn: 0.3097477	total: 5.75s	remaining: 5.14s
# 528:	learn: 0.3096286	total: 5.77s	remaining: 5.14s
# 529:	learn: 0.3093030	total: 5.79s	remaining: 5.13s
# 530:	learn: 0.3090784	total: 5.8s	remaining: 5.12s
# 531:	learn: 0.3087724	total: 5.81s	remaining: 5.11s
# 532:	learn: 0.3085806	total: 5.83s	remaining: 5.11s
# 533:	learn: 0.3083253	total: 5.85s	remaining: 5.11s
# 534:	learn: 0.3081614	total: 5.88s	remaining: 5.11s
# 535:	learn: 0.3079982	total: 5.9s	remaining: 5.1s
# 536:	learn: 0.3077431	total: 5.91s	remaining: 5.1s
# 537:	learn: 0.3075901	total: 5.93s	remaining: 5.09s
# 538:	learn: 0.3074383	total: 5.96s	remaining: 5.1s
# 539:	learn: 0.3071382	total: 5.98s	remaining: 5.1s
# 540:	learn: 0.3066166	total: 6.01s	remaining: 5.09s
# 541:	learn: 0.3064703	total: 6.03s	remaining: 5.09s
# 542:	learn: 0.3062760	total: 6.05s	remaining: 5.09s
# 543:	learn: 0.3060038	total: 6.06s	remaining: 5.08s
# 544:	learn: 0.3057007	total: 6.07s	remaining: 5.07s
# 545:	learn: 0.3055322	total: 6.08s	remaining: 5.06s
# 546:	learn: 0.3052604	total: 6.09s	remaining: 5.05s
# 547:	learn: 0.3050452	total: 6.11s	remaining: 5.04s
# 548:	learn: 0.3048869	total: 6.12s	remaining: 5.02s
# 549:	learn: 0.3043939	total: 6.13s	remaining: 5.01s
# 550:	learn: 0.3041612	total: 6.14s	remaining: 5s
# 551:	learn: 0.3038066	total: 6.16s	remaining: 5s
# 552:	learn: 0.3034934	total: 6.17s	remaining: 4.99s
# 553:	learn: 0.3033267	total: 6.18s	remaining: 4.97s
# 554:	learn: 0.3029830	total: 6.19s	remaining: 4.96s
# 555:	learn: 0.3028459	total: 6.2s	remaining: 4.95s
# 556:	learn: 0.3025551	total: 6.22s	remaining: 4.95s
# 557:	learn: 0.3023448	total: 6.24s	remaining: 4.94s
# 558:	learn: 0.3020697	total: 6.26s	remaining: 4.94s
# 559:	learn: 0.3016740	total: 6.28s	remaining: 4.93s
# 560:	learn: 0.3014662	total: 6.3s	remaining: 4.93s
# 561:	learn: 0.3012050	total: 6.32s	remaining: 4.93s
# 562:	learn: 0.3008615	total: 6.34s	remaining: 4.92s
# 563:	learn: 0.3006587	total: 6.35s	remaining: 4.91s
# 564:	learn: 0.3004823	total: 6.37s	remaining: 4.91s
# 565:	learn: 0.3003586	total: 6.38s	remaining: 4.89s
# 566:	learn: 0.2998743	total: 6.41s	remaining: 4.9s
# 567:	learn: 0.2996460	total: 6.43s	remaining: 4.89s
# 568:	learn: 0.2993114	total: 6.45s	remaining: 4.89s
# 569:	learn: 0.2991973	total: 6.47s	remaining: 4.88s
# 570:	learn: 0.2990764	total: 6.49s	remaining: 4.88s
# 571:	learn: 0.2989282	total: 6.51s	remaining: 4.87s
# 572:	learn: 0.2987398	total: 6.54s	remaining: 4.87s
# 573:	learn: 0.2983373	total: 6.56s	remaining: 4.87s
# 574:	learn: 0.2981381	total: 6.58s	remaining: 4.87s
# 575:	learn: 0.2978218	total: 6.6s	remaining: 4.86s
# 576:	learn: 0.2975589	total: 6.62s	remaining: 4.85s
# 577:	learn: 0.2973300	total: 6.64s	remaining: 4.85s
# 578:	learn: 0.2969957	total: 6.65s	remaining: 4.84s
# 579:	learn: 0.2967617	total: 6.66s	remaining: 4.82s
# 580:	learn: 0.2965806	total: 6.67s	remaining: 4.81s
# 581:	learn: 0.2963773	total: 6.69s	remaining: 4.81s
# 582:	learn: 0.2962147	total: 6.71s	remaining: 4.8s
# 583:	learn: 0.2959714	total: 6.72s	remaining: 4.79s
# 584:	learn: 0.2958240	total: 6.73s	remaining: 4.77s
# 585:	learn: 0.2956755	total: 6.74s	remaining: 4.76s
# 586:	learn: 0.2955340	total: 6.76s	remaining: 4.76s
# 587:	learn: 0.2951584	total: 6.79s	remaining: 4.75s
# 588:	learn: 0.2948047	total: 6.8s	remaining: 4.74s
# 589:	learn: 0.2947093	total: 6.81s	remaining: 4.73s
# 590:	learn: 0.2945140	total: 6.82s	remaining: 4.72s
# 591:	learn: 0.2943780	total: 6.83s	remaining: 4.71s
# 592:	learn: 0.2940224	total: 6.84s	remaining: 4.69s
# 593:	learn: 0.2936394	total: 6.85s	remaining: 4.68s
# 594:	learn: 0.2932298	total: 6.87s	remaining: 4.67s
# 595:	learn: 0.2930773	total: 6.88s	remaining: 4.67s
# 596:	learn: 0.2928574	total: 6.89s	remaining: 4.65s
# 597:	learn: 0.2926032	total: 6.9s	remaining: 4.64s
# 598:	learn: 0.2924433	total: 6.91s	remaining: 4.63s
# 599:	learn: 0.2921845	total: 6.93s	remaining: 4.62s
# 600:	learn: 0.2919394	total: 6.95s	remaining: 4.61s
# 601:	learn: 0.2918490	total: 6.97s	remaining: 4.61s
# 602:	learn: 0.2917226	total: 7.01s	remaining: 4.61s
# 603:	learn: 0.2914194	total: 7.03s	remaining: 4.61s
# 604:	learn: 0.2912592	total: 7.05s	remaining: 4.6s
# 605:	learn: 0.2909662	total: 7.07s	remaining: 4.6s
# 606:	learn: 0.2906669	total: 7.09s	remaining: 4.59s
# 607:	learn: 0.2903708	total: 7.11s	remaining: 4.59s
# 608:	learn: 0.2900924	total: 7.13s	remaining: 4.58s
# 609:	learn: 0.2898733	total: 7.15s	remaining: 4.57s
# 610:	learn: 0.2895832	total: 7.17s	remaining: 4.57s
# 611:	learn: 0.2892269	total: 7.19s	remaining: 4.56s
# 612:	learn: 0.2890530	total: 7.22s	remaining: 4.56s
# 613:	learn: 0.2889394	total: 7.24s	remaining: 4.55s
# 614:	learn: 0.2886629	total: 7.27s	remaining: 4.55s
# 615:	learn: 0.2882888	total: 7.29s	remaining: 4.54s
# 616:	learn: 0.2881433	total: 7.31s	remaining: 4.54s
# 617:	learn: 0.2880383	total: 7.33s	remaining: 4.53s
# 618:	learn: 0.2877439	total: 7.35s	remaining: 4.53s
# 619:	learn: 0.2876114	total: 7.37s	remaining: 4.52s
# 620:	learn: 0.2874842	total: 7.39s	remaining: 4.51s
# 621:	learn: 0.2872349	total: 7.41s	remaining: 4.5s
# 622:	learn: 0.2870144	total: 7.44s	remaining: 4.5s
# 623:	learn: 0.2867565	total: 7.46s	remaining: 4.5s
# 624:	learn: 0.2865625	total: 7.48s	remaining: 4.49s
# 625:	learn: 0.2862333	total: 7.5s	remaining: 4.48s
# 626:	learn: 0.2859246	total: 7.53s	remaining: 4.48s
# 627:	learn: 0.2857395	total: 7.55s	remaining: 4.47s
# 628:	learn: 0.2855833	total: 7.57s	remaining: 4.46s
# 629:	learn: 0.2854323	total: 7.59s	remaining: 4.46s
# 630:	learn: 0.2852116	total: 7.61s	remaining: 4.45s
# 631:	learn: 0.2850518	total: 7.62s	remaining: 4.44s
# 632:	learn: 0.2849337	total: 7.64s	remaining: 4.43s
# 633:	learn: 0.2847195	total: 7.67s	remaining: 4.43s
# 634:	learn: 0.2845501	total: 7.69s	remaining: 4.42s
# 635:	learn: 0.2843595	total: 7.71s	remaining: 4.41s
# 636:	learn: 0.2840081	total: 7.72s	remaining: 4.4s
# 637:	learn: 0.2838486	total: 7.75s	remaining: 4.39s
# 638:	learn: 0.2836354	total: 7.77s	remaining: 4.39s
# 639:	learn: 0.2834909	total: 7.79s	remaining: 4.38s
# 640:	learn: 0.2833368	total: 7.82s	remaining: 4.38s
# 641:	learn: 0.2830055	total: 7.85s	remaining: 4.38s
# 642:	learn: 0.2828873	total: 7.87s	remaining: 4.37s
# 643:	learn: 0.2827372	total: 7.89s	remaining: 4.36s
# 644:	learn: 0.2825757	total: 7.92s	remaining: 4.36s
# 645:	learn: 0.2823818	total: 7.93s	remaining: 4.35s
# 646:	learn: 0.2822410	total: 7.94s	remaining: 4.33s
# 647:	learn: 0.2820915	total: 7.95s	remaining: 4.32s
# 648:	learn: 0.2818112	total: 7.96s	remaining: 4.31s
# 649:	learn: 0.2816824	total: 7.97s	remaining: 4.29s
# 650:	learn: 0.2814213	total: 7.98s	remaining: 4.28s
# 651:	learn: 0.2812449	total: 7.99s	remaining: 4.26s
# 652:	learn: 0.2811227	total: 8s	remaining: 4.25s
# 653:	learn: 0.2809097	total: 8.01s	remaining: 4.24s
# 654:	learn: 0.2806748	total: 8.02s	remaining: 4.22s
# 655:	learn: 0.2804866	total: 8.03s	remaining: 4.21s
# 656:	learn: 0.2803314	total: 8.04s	remaining: 4.2s
# 657:	learn: 0.2801904	total: 8.05s	remaining: 4.18s
# 658:	learn: 0.2800234	total: 8.06s	remaining: 4.17s
# 659:	learn: 0.2797888	total: 8.07s	remaining: 4.16s
# 660:	learn: 0.2795820	total: 8.07s	remaining: 4.14s
# 661:	learn: 0.2794641	total: 8.08s	remaining: 4.13s
# 662:	learn: 0.2792718	total: 8.09s	remaining: 4.11s
# 663:	learn: 0.2790584	total: 8.1s	remaining: 4.1s
# 664:	learn: 0.2788925	total: 8.11s	remaining: 4.08s
# 665:	learn: 0.2787541	total: 8.12s	remaining: 4.07s
# 666:	learn: 0.2785369	total: 8.13s	remaining: 4.06s
# 667:	learn: 0.2784280	total: 8.13s	remaining: 4.04s
# 668:	learn: 0.2782047	total: 8.14s	remaining: 4.03s
# 669:	learn: 0.2780709	total: 8.15s	remaining: 4.01s
# 670:	learn: 0.2778213	total: 8.16s	remaining: 4s
# 671:	learn: 0.2776930	total: 8.17s	remaining: 3.99s
# 672:	learn: 0.2775285	total: 8.18s	remaining: 3.97s
# 673:	learn: 0.2773872	total: 8.18s	remaining: 3.96s
# 674:	learn: 0.2771464	total: 8.19s	remaining: 3.94s
# 675:	learn: 0.2769617	total: 8.2s	remaining: 3.93s
# 676:	learn: 0.2767449	total: 8.21s	remaining: 3.92s
# 677:	learn: 0.2765239	total: 8.22s	remaining: 3.9s
# 678:	learn: 0.2763578	total: 8.23s	remaining: 3.89s
# 679:	learn: 0.2761596	total: 8.25s	remaining: 3.88s
# 680:	learn: 0.2760069	total: 8.26s	remaining: 3.87s
# 681:	learn: 0.2757791	total: 8.27s	remaining: 3.85s
# 682:	learn: 0.2756476	total: 8.28s	remaining: 3.84s
# 683:	learn: 0.2755138	total: 8.28s	remaining: 3.83s
# 684:	learn: 0.2752523	total: 8.29s	remaining: 3.81s
# 685:	learn: 0.2749797	total: 8.3s	remaining: 3.8s
# 686:	learn: 0.2748745	total: 8.31s	remaining: 3.79s
# 687:	learn: 0.2746537	total: 8.32s	remaining: 3.77s
# 688:	learn: 0.2744318	total: 8.33s	remaining: 3.76s
# 689:	learn: 0.2742267	total: 8.34s	remaining: 3.75s
# 690:	learn: 0.2740645	total: 8.35s	remaining: 3.73s
# 691:	learn: 0.2738864	total: 8.36s	remaining: 3.72s
# 692:	learn: 0.2736934	total: 8.37s	remaining: 3.71s
# 693:	learn: 0.2733730	total: 8.38s	remaining: 3.69s
# 694:	learn: 0.2731896	total: 8.38s	remaining: 3.68s
# 695:	learn: 0.2730718	total: 8.39s	remaining: 3.67s
# 696:	learn: 0.2729431	total: 8.4s	remaining: 3.65s
# 697:	learn: 0.2727756	total: 8.41s	remaining: 3.64s
# 698:	learn: 0.2726086	total: 8.42s	remaining: 3.63s
# 699:	learn: 0.2724217	total: 8.43s	remaining: 3.61s
# 700:	learn: 0.2721898	total: 8.44s	remaining: 3.6s
# 701:	learn: 0.2720940	total: 8.45s	remaining: 3.58s
# 702:	learn: 0.2718222	total: 8.46s	remaining: 3.57s
# 703:	learn: 0.2716063	total: 8.47s	remaining: 3.56s
# 704:	learn: 0.2714165	total: 8.48s	remaining: 3.55s
# 705:	learn: 0.2712714	total: 8.49s	remaining: 3.53s
# 706:	learn: 0.2711775	total: 8.49s	remaining: 3.52s
# 707:	learn: 0.2710973	total: 8.5s	remaining: 3.51s
# 708:	learn: 0.2709528	total: 8.51s	remaining: 3.49s
# 709:	learn: 0.2708620	total: 8.52s	remaining: 3.48s
# 710:	learn: 0.2707022	total: 8.53s	remaining: 3.47s
# 711:	learn: 0.2706122	total: 8.55s	remaining: 3.46s
# 712:	learn: 0.2705152	total: 8.56s	remaining: 3.45s
# 713:	learn: 0.2702679	total: 8.57s	remaining: 3.43s
# 714:	learn: 0.2700983	total: 8.58s	remaining: 3.42s
# 715:	learn: 0.2698763	total: 8.59s	remaining: 3.41s
# 716:	learn: 0.2696447	total: 8.6s	remaining: 3.39s
# 717:	learn: 0.2695074	total: 8.61s	remaining: 3.38s
# 718:	learn: 0.2693986	total: 8.62s	remaining: 3.37s
# 719:	learn: 0.2692526	total: 8.63s	remaining: 3.35s
# 720:	learn: 0.2690390	total: 8.63s	remaining: 3.34s
# 721:	learn: 0.2688695	total: 8.64s	remaining: 3.33s
# 722:	learn: 0.2687533	total: 8.65s	remaining: 3.31s
# 723:	learn: 0.2685046	total: 8.67s	remaining: 3.3s
# 724:	learn: 0.2682754	total: 8.68s	remaining: 3.29s
# 725:	learn: 0.2681482	total: 8.69s	remaining: 3.28s
# 726:	learn: 0.2679618	total: 8.69s	remaining: 3.27s
# 727:	learn: 0.2678315	total: 8.7s	remaining: 3.25s
# 728:	learn: 0.2676183	total: 8.71s	remaining: 3.24s
# 729:	learn: 0.2674757	total: 8.72s	remaining: 3.23s
# 730:	learn: 0.2673219	total: 8.73s	remaining: 3.21s
# 731:	learn: 0.2671660	total: 8.74s	remaining: 3.2s
# 732:	learn: 0.2668696	total: 8.75s	remaining: 3.19s
# 733:	learn: 0.2667830	total: 8.76s	remaining: 3.17s
# 734:	learn: 0.2666000	total: 8.77s	remaining: 3.16s
# 735:	learn: 0.2664421	total: 8.78s	remaining: 3.15s
# 736:	learn: 0.2662686	total: 8.79s	remaining: 3.14s
# 737:	learn: 0.2661232	total: 8.8s	remaining: 3.12s
# 738:	learn: 0.2659656	total: 8.8s	remaining: 3.11s
# 739:	learn: 0.2658002	total: 8.81s	remaining: 3.1s
# 740:	learn: 0.2655059	total: 8.82s	remaining: 3.08s
# 741:	learn: 0.2653766	total: 8.83s	remaining: 3.07s
# 742:	learn: 0.2651505	total: 8.84s	remaining: 3.06s
# 743:	learn: 0.2646732	total: 8.85s	remaining: 3.04s
# 744:	learn: 0.2645441	total: 8.86s	remaining: 3.03s
# 745:	learn: 0.2643485	total: 8.87s	remaining: 3.02s
# 746:	learn: 0.2641966	total: 8.88s	remaining: 3.01s
# 747:	learn: 0.2640811	total: 8.89s	remaining: 3s
# 748:	learn: 0.2639170	total: 8.9s	remaining: 2.98s
# 749:	learn: 0.2637183	total: 8.91s	remaining: 2.97s
# 750:	learn: 0.2635588	total: 8.92s	remaining: 2.96s
# 751:	learn: 0.2634558	total: 8.93s	remaining: 2.94s
# 752:	learn: 0.2632692	total: 8.93s	remaining: 2.93s
# 753:	learn: 0.2631349	total: 8.94s	remaining: 2.92s
# 754:	learn: 0.2628619	total: 8.95s	remaining: 2.9s
# 755:	learn: 0.2627274	total: 8.96s	remaining: 2.89s
# 756:	learn: 0.2625403	total: 8.97s	remaining: 2.88s
# 757:	learn: 0.2621698	total: 8.98s	remaining: 2.87s
# 758:	learn: 0.2620155	total: 8.99s	remaining: 2.85s
# 759:	learn: 0.2617488	total: 9s	remaining: 2.84s
# 760:	learn: 0.2614903	total: 9.01s	remaining: 2.83s
# 761:	learn: 0.2613416	total: 9.02s	remaining: 2.82s
# 762:	learn: 0.2612371	total: 9.02s	remaining: 2.8s
# 763:	learn: 0.2610734	total: 9.03s	remaining: 2.79s
# 764:	learn: 0.2609552	total: 9.04s	remaining: 2.78s
# 765:	learn: 0.2608044	total: 9.05s	remaining: 2.76s
# 766:	learn: 0.2605573	total: 9.06s	remaining: 2.75s
# 767:	learn: 0.2604482	total: 9.07s	remaining: 2.74s
# 768:	learn: 0.2603412	total: 9.09s	remaining: 2.73s
# 769:	learn: 0.2602230	total: 9.1s	remaining: 2.72s
# 770:	learn: 0.2600565	total: 9.11s	remaining: 2.7s
# 771:	learn: 0.2599491	total: 9.12s	remaining: 2.69s
# 772:	learn: 0.2598269	total: 9.12s	remaining: 2.68s
# 773:	learn: 0.2594970	total: 9.13s	remaining: 2.67s
# 774:	learn: 0.2592573	total: 9.14s	remaining: 2.65s
# 775:	learn: 0.2591973	total: 9.15s	remaining: 2.64s
# 776:	learn: 0.2589736	total: 9.16s	remaining: 2.63s
# 777:	learn: 0.2588803	total: 9.17s	remaining: 2.62s
# 778:	learn: 0.2586145	total: 9.17s	remaining: 2.6s
# 779:	learn: 0.2584503	total: 9.18s	remaining: 2.59s
# 780:	learn: 0.2582860	total: 9.19s	remaining: 2.58s
# 781:	learn: 0.2581610	total: 9.2s	remaining: 2.56s
# 782:	learn: 0.2579927	total: 9.21s	remaining: 2.55s
# 783:	learn: 0.2576082	total: 9.22s	remaining: 2.54s
# 784:	learn: 0.2575371	total: 9.23s	remaining: 2.53s
# 785:	learn: 0.2573555	total: 9.24s	remaining: 2.52s
# 786:	learn: 0.2572369	total: 9.25s	remaining: 2.5s
# 787:	learn: 0.2570304	total: 9.26s	remaining: 2.49s
# 788:	learn: 0.2568856	total: 9.26s	remaining: 2.48s
# 789:	learn: 0.2566168	total: 9.27s	remaining: 2.46s
# 790:	learn: 0.2564484	total: 9.28s	remaining: 2.45s
# 791:	learn: 0.2563393	total: 9.29s	remaining: 2.44s
# 792:	learn: 0.2562744	total: 9.3s	remaining: 2.43s
# 793:	learn: 0.2561264	total: 9.31s	remaining: 2.42s
# 794:	learn: 0.2559976	total: 9.32s	remaining: 2.4s
# 795:	learn: 0.2559009	total: 9.33s	remaining: 2.39s
# 796:	learn: 0.2557643	total: 9.34s	remaining: 2.38s
# 797:	learn: 0.2555775	total: 9.35s	remaining: 2.37s
# 798:	learn: 0.2553399	total: 9.36s	remaining: 2.35s
# 799:	learn: 0.2551857	total: 9.37s	remaining: 2.34s
# 800:	learn: 0.2550614	total: 9.38s	remaining: 2.33s
# 801:	learn: 0.2548469	total: 9.38s	remaining: 2.32s
# 802:	learn: 0.2545952	total: 9.39s	remaining: 2.3s
# 803:	learn: 0.2544772	total: 9.4s	remaining: 2.29s
# 804:	learn: 0.2542435	total: 9.41s	remaining: 2.28s
# 805:	learn: 0.2541224	total: 9.42s	remaining: 2.27s
# 806:	learn: 0.2539948	total: 9.43s	remaining: 2.25s
# 807:	learn: 0.2538688	total: 9.44s	remaining: 2.24s
# 808:	learn: 0.2536008	total: 9.45s	remaining: 2.23s
# 809:	learn: 0.2534875	total: 9.46s	remaining: 2.22s
# 810:	learn: 0.2533321	total: 9.46s	remaining: 2.21s
# 811:	learn: 0.2531659	total: 9.47s	remaining: 2.19s
# 812:	learn: 0.2528456	total: 9.48s	remaining: 2.18s
# 813:	learn: 0.2527648	total: 9.49s	remaining: 2.17s
# 814:	learn: 0.2524492	total: 9.5s	remaining: 2.16s
# 815:	learn: 0.2522886	total: 9.51s	remaining: 2.15s
# 816:	learn: 0.2521146	total: 9.52s	remaining: 2.13s
# 817:	learn: 0.2519722	total: 9.54s	remaining: 2.12s
# 818:	learn: 0.2518743	total: 9.55s	remaining: 2.11s
# 819:	learn: 0.2517603	total: 9.56s	remaining: 2.1s
# 820:	learn: 0.2516780	total: 9.57s	remaining: 2.09s
# 821:	learn: 0.2515852	total: 9.58s	remaining: 2.08s
# 822:	learn: 0.2514600	total: 9.59s	remaining: 2.06s
# 823:	learn: 0.2513312	total: 9.6s	remaining: 2.05s
# 824:	learn: 0.2512271	total: 9.61s	remaining: 2.04s
# 825:	learn: 0.2510993	total: 9.62s	remaining: 2.03s
# 826:	learn: 0.2508693	total: 9.63s	remaining: 2.01s
# 827:	learn: 0.2507274	total: 9.64s	remaining: 2s
# 828:	learn: 0.2504975	total: 9.64s	remaining: 1.99s
# 829:	learn: 0.2503454	total: 9.65s	remaining: 1.98s
# 830:	learn: 0.2501386	total: 9.66s	remaining: 1.97s
# 831:	learn: 0.2500038	total: 9.67s	remaining: 1.95s
# 832:	learn: 0.2498766	total: 9.68s	remaining: 1.94s
# 833:	learn: 0.2496741	total: 9.69s	remaining: 1.93s
# 834:	learn: 0.2496132	total: 9.71s	remaining: 1.92s
# 835:	learn: 0.2493826	total: 9.71s	remaining: 1.91s
# 836:	learn: 0.2491896	total: 9.72s	remaining: 1.89s
# 837:	learn: 0.2490740	total: 9.73s	remaining: 1.88s
# 838:	learn: 0.2488422	total: 9.74s	remaining: 1.87s
# 839:	learn: 0.2487436	total: 9.75s	remaining: 1.86s
# 840:	learn: 0.2486178	total: 9.76s	remaining: 1.84s
# 841:	learn: 0.2485092	total: 9.77s	remaining: 1.83s
# 842:	learn: 0.2483868	total: 9.77s	remaining: 1.82s
# 843:	learn: 0.2482226	total: 9.78s	remaining: 1.81s
# 844:	learn: 0.2480594	total: 9.79s	remaining: 1.79s
# 845:	learn: 0.2479023	total: 9.8s	remaining: 1.78s
# 846:	learn: 0.2475848	total: 9.81s	remaining: 1.77s
# 847:	learn: 0.2474870	total: 9.82s	remaining: 1.76s
# 848:	learn: 0.2473692	total: 9.83s	remaining: 1.75s
# 849:	learn: 0.2472834	total: 9.84s	remaining: 1.74s
# 850:	learn: 0.2471398	total: 9.84s	remaining: 1.72s
# 851:	learn: 0.2470708	total: 9.85s	remaining: 1.71s
# 852:	learn: 0.2468802	total: 9.86s	remaining: 1.7s
# 853:	learn: 0.2467911	total: 9.87s	remaining: 1.69s
# 854:	learn: 0.2466563	total: 9.88s	remaining: 1.68s
# 855:	learn: 0.2465665	total: 9.89s	remaining: 1.66s
# 856:	learn: 0.2463861	total: 9.9s	remaining: 1.65s
# 857:	learn: 0.2463095	total: 9.91s	remaining: 1.64s
# 858:	learn: 0.2462149	total: 9.92s	remaining: 1.63s
# 859:	learn: 0.2460919	total: 9.93s	remaining: 1.61s
# 860:	learn: 0.2459463	total: 9.93s	remaining: 1.6s
# 861:	learn: 0.2458044	total: 9.94s	remaining: 1.59s
# 862:	learn: 0.2456476	total: 9.95s	remaining: 1.58s
# 863:	learn: 0.2455406	total: 9.96s	remaining: 1.57s
# 864:	learn: 0.2452225	total: 9.97s	remaining: 1.56s
# 865:	learn: 0.2451316	total: 9.98s	remaining: 1.54s
# 866:	learn: 0.2450350	total: 9.99s	remaining: 1.53s
# 867:	learn: 0.2449264	total: 10s	remaining: 1.52s
# 868:	learn: 0.2447151	total: 10s	remaining: 1.51s
# 869:	learn: 0.2446066	total: 10s	remaining: 1.5s
# 870:	learn: 0.2445062	total: 10s	remaining: 1.48s
# 871:	learn: 0.2443826	total: 10s	remaining: 1.47s
# 872:	learn: 0.2442384	total: 10s	remaining: 1.46s
# 873:	learn: 0.2441267	total: 10s	remaining: 1.45s
# 874:	learn: 0.2440255	total: 10.1s	remaining: 1.44s
# 875:	learn: 0.2439180	total: 10.1s	remaining: 1.43s
# 876:	learn: 0.2437722	total: 10.1s	remaining: 1.41s
# 877:	learn: 0.2435786	total: 10.1s	remaining: 1.4s
# 878:	learn: 0.2434991	total: 10.1s	remaining: 1.39s
# 879:	learn: 0.2434303	total: 10.1s	remaining: 1.38s
# 880:	learn: 0.2432340	total: 10.1s	remaining: 1.37s
# 881:	learn: 0.2431046	total: 10.1s	remaining: 1.36s
# 882:	learn: 0.2429475	total: 10.1s	remaining: 1.34s
# 883:	learn: 0.2428859	total: 10.2s	remaining: 1.33s
# 884:	learn: 0.2426542	total: 10.2s	remaining: 1.32s
# 885:	learn: 0.2425370	total: 10.2s	remaining: 1.31s
# 886:	learn: 0.2423247	total: 10.2s	remaining: 1.3s
# 887:	learn: 0.2422075	total: 10.2s	remaining: 1.28s
# 888:	learn: 0.2420955	total: 10.2s	remaining: 1.27s
# 889:	learn: 0.2419990	total: 10.2s	remaining: 1.26s
# 890:	learn: 0.2418182	total: 10.2s	remaining: 1.25s
# 891:	learn: 0.2416991	total: 10.2s	remaining: 1.24s
# 892:	learn: 0.2415414	total: 10.2s	remaining: 1.23s
# 893:	learn: 0.2413842	total: 10.2s	remaining: 1.21s
# 894:	learn: 0.2412582	total: 10.2s	remaining: 1.2s
# 895:	learn: 0.2411109	total: 10.3s	remaining: 1.19s
# 896:	learn: 0.2410230	total: 10.3s	remaining: 1.18s
# 897:	learn: 0.2409347	total: 10.3s	remaining: 1.17s
# 898:	learn: 0.2407341	total: 10.3s	remaining: 1.16s
# 899:	learn: 0.2406382	total: 10.3s	remaining: 1.14s
# 900:	learn: 0.2404448	total: 10.3s	remaining: 1.13s
# 901:	learn: 0.2403675	total: 10.3s	remaining: 1.12s
# 902:	learn: 0.2402286	total: 10.3s	remaining: 1.11s
# 903:	learn: 0.2399816	total: 10.3s	remaining: 1.1s
# 904:	learn: 0.2398652	total: 10.3s	remaining: 1.08s
# 905:	learn: 0.2396741	total: 10.3s	remaining: 1.07s
# 906:	learn: 0.2395768	total: 10.4s	remaining: 1.06s
# 907:	learn: 0.2393977	total: 10.4s	remaining: 1.05s
# 908:	learn: 0.2393014	total: 10.4s	remaining: 1.04s
# 909:	learn: 0.2391854	total: 10.4s	remaining: 1.03s
# 910:	learn: 0.2390935	total: 10.4s	remaining: 1.01s
# 911:	learn: 0.2388513	total: 10.4s	remaining: 1s
# 912:	learn: 0.2387272	total: 10.4s	remaining: 992ms
# 913:	learn: 0.2386067	total: 10.4s	remaining: 980ms
# 914:	learn: 0.2383626	total: 10.4s	remaining: 968ms
# 915:	learn: 0.2381922	total: 10.4s	remaining: 957ms
# 916:	learn: 0.2380450	total: 10.4s	remaining: 945ms
# 917:	learn: 0.2379646	total: 10.5s	remaining: 934ms
# 918:	learn: 0.2377714	total: 10.5s	remaining: 923ms
# 919:	learn: 0.2375744	total: 10.5s	remaining: 911ms
# 920:	learn: 0.2372975	total: 10.5s	remaining: 899ms
# 921:	learn: 0.2371707	total: 10.5s	remaining: 888ms
# 922:	learn: 0.2370582	total: 10.5s	remaining: 877ms
# 923:	learn: 0.2369059	total: 10.5s	remaining: 865ms
# 924:	learn: 0.2368140	total: 10.5s	remaining: 853ms
# 925:	learn: 0.2366962	total: 10.5s	remaining: 843ms
# 926:	learn: 0.2365947	total: 10.6s	remaining: 831ms
# 927:	learn: 0.2365236	total: 10.6s	remaining: 820ms
# 928:	learn: 0.2363914	total: 10.6s	remaining: 808ms
# 929:	learn: 0.2362856	total: 10.6s	remaining: 797ms
# 930:	learn: 0.2361449	total: 10.6s	remaining: 785ms
# 931:	learn: 0.2358879	total: 10.6s	remaining: 773ms
# ...
# 692:	learn: 0.2737130	total: 7.61s	remaining: 3.37s
# 693:	learn: 0.2735870	total: 7.63s	remaining: 3.36s
# 694:	learn: 0.2733964	total: 7.64s	remaining: 3.35s
# 695:	learn: 0.2731724	total: 7.66s	remaining: 3.34s
# 696:	learn: 0.2729638	total: 7.67s	remaining: 3.33s
# 697:	learn: 0.2728249	total: 7.68s	remaining: 3.32s
# 698:	learn: 0.2726998	total: 7.69s	remaining: 3.31s
# 699:	learn: 0.2723218	total: 7.71s	remaining: 3.3s
# 700:	learn: 0.2721941	total: 7.73s	remaining: 3.3s
# 701:	learn: 0.2720143	total: 7.75s	remaining: 3.29s
# 702:	learn: 0.2717015	total: 7.76s	remaining: 3.28s
# 703:	learn: 0.2716267	total: 7.77s	remaining: 3.27s
# 704:	learn: 0.2713621	total: 7.78s	remaining: 3.26s
# 705:	learn: 0.2711642	total: 7.79s	remaining: 3.25s
# 706:	learn: 0.2709225	total: 7.82s	remaining: 3.24s
# 707:	learn: 0.2707440	total: 7.83s	remaining: 3.23s
# 708:	learn: 0.2706218	total: 7.84s	remaining: 3.22s
# 709:	learn: 0.2704722	total: 7.85s	remaining: 3.21s
# 710:	learn: 0.2703139	total: 7.87s	remaining: 3.2s
# 711:	learn: 0.2701504	total: 7.88s	remaining: 3.19s
# 712:	learn: 0.2699087	total: 7.9s	remaining: 3.18s
# 713:	learn: 0.2696602	total: 7.93s	remaining: 3.18s
# 714:	learn: 0.2694948	total: 7.95s	remaining: 3.17s
# 715:	learn: 0.2693081	total: 7.97s	remaining: 3.16s
# 716:	learn: 0.2690688	total: 7.99s	remaining: 3.15s
# 717:	learn: 0.2689276	total: 8.02s	remaining: 3.15s
# 718:	learn: 0.2687822	total: 8.05s	remaining: 3.14s
# 719:	learn: 0.2686605	total: 8.07s	remaining: 3.14s
# 720:	learn: 0.2685534	total: 8.09s	remaining: 3.13s
# 721:	learn: 0.2683585	total: 8.11s	remaining: 3.12s
# 722:	learn: 0.2682434	total: 8.13s	remaining: 3.11s
# 723:	learn: 0.2680290	total: 8.15s	remaining: 3.11s
# 724:	learn: 0.2678337	total: 8.17s	remaining: 3.1s
# 725:	learn: 0.2677328	total: 8.19s	remaining: 3.09s
# 726:	learn: 0.2675788	total: 8.21s	remaining: 3.08s
# 727:	learn: 0.2674335	total: 8.24s	remaining: 3.08s
# 728:	learn: 0.2672282	total: 8.27s	remaining: 3.07s
# 729:	learn: 0.2670486	total: 8.29s	remaining: 3.06s
# 730:	learn: 0.2669443	total: 8.31s	remaining: 3.06s
# 731:	learn: 0.2668545	total: 8.33s	remaining: 3.05s
# 732:	learn: 0.2667204	total: 8.35s	remaining: 3.04s
# 733:	learn: 0.2666433	total: 8.37s	remaining: 3.03s
# 734:	learn: 0.2665537	total: 8.38s	remaining: 3.02s
# 735:	learn: 0.2663815	total: 8.4s	remaining: 3.01s
# 736:	learn: 0.2660640	total: 8.43s	remaining: 3.01s
# 737:	learn: 0.2656117	total: 8.46s	remaining: 3s
# 738:	learn: 0.2655293	total: 8.48s	remaining: 2.99s
# 739:	learn: 0.2654131	total: 8.49s	remaining: 2.98s
# 740:	learn: 0.2651937	total: 8.52s	remaining: 2.98s
# 741:	learn: 0.2648145	total: 8.54s	remaining: 2.97s
# 742:	learn: 0.2646973	total: 8.56s	remaining: 2.96s
# 743:	learn: 0.2645363	total: 8.59s	remaining: 2.95s
# 744:	learn: 0.2643649	total: 8.6s	remaining: 2.94s
# 745:	learn: 0.2642189	total: 8.62s	remaining: 2.94s
# 746:	learn: 0.2640831	total: 8.63s	remaining: 2.92s
# 747:	learn: 0.2638639	total: 8.65s	remaining: 2.92s
# 748:	learn: 0.2637461	total: 8.68s	remaining: 2.91s
# 749:	learn: 0.2635332	total: 8.7s	remaining: 2.9s
# 750:	learn: 0.2634124	total: 8.72s	remaining: 2.89s
# 751:	learn: 0.2632178	total: 8.74s	remaining: 2.88s
# 752:	learn: 0.2631394	total: 8.76s	remaining: 2.87s
# 753:	learn: 0.2630188	total: 8.77s	remaining: 2.86s
# 754:	learn: 0.2628264	total: 8.78s	remaining: 2.85s
# 755:	learn: 0.2626298	total: 8.79s	remaining: 2.84s
# 756:	learn: 0.2624498	total: 8.81s	remaining: 2.83s
# 757:	learn: 0.2623207	total: 8.82s	remaining: 2.81s
# 758:	learn: 0.2621468	total: 8.84s	remaining: 2.81s
# 759:	learn: 0.2620631	total: 8.87s	remaining: 2.8s
# 760:	learn: 0.2619200	total: 8.89s	remaining: 2.79s
# 761:	learn: 0.2617947	total: 8.91s	remaining: 2.78s
# 762:	learn: 0.2616956	total: 8.93s	remaining: 2.77s
# 763:	learn: 0.2614440	total: 8.95s	remaining: 2.76s
# 764:	learn: 0.2613252	total: 8.96s	remaining: 2.75s
# 765:	learn: 0.2612444	total: 8.98s	remaining: 2.74s
# 766:	learn: 0.2610879	total: 9s	remaining: 2.73s
# 767:	learn: 0.2610242	total: 9.02s	remaining: 2.73s
# 768:	learn: 0.2608733	total: 9.04s	remaining: 2.72s
# 769:	learn: 0.2606474	total: 9.05s	remaining: 2.7s
# 770:	learn: 0.2604443	total: 9.07s	remaining: 2.69s
# 771:	learn: 0.2603306	total: 9.11s	remaining: 2.69s
# 772:	learn: 0.2601858	total: 9.13s	remaining: 2.68s
# 773:	learn: 0.2600593	total: 9.15s	remaining: 2.67s
# 774:	learn: 0.2598996	total: 9.17s	remaining: 2.66s
# 775:	learn: 0.2596782	total: 9.2s	remaining: 2.65s
# 776:	learn: 0.2595009	total: 9.22s	remaining: 2.65s
# 777:	learn: 0.2593334	total: 9.24s	remaining: 2.64s
# 778:	learn: 0.2592164	total: 9.26s	remaining: 2.63s
# 779:	learn: 0.2590663	total: 9.29s	remaining: 2.62s
# 780:	learn: 0.2588596	total: 9.31s	remaining: 2.61s
# 781:	learn: 0.2586452	total: 9.33s	remaining: 2.6s
# 782:	learn: 0.2585083	total: 9.35s	remaining: 2.59s
# 783:	learn: 0.2582398	total: 9.37s	remaining: 2.58s
# 784:	learn: 0.2581512	total: 9.39s	remaining: 2.57s
# 785:	learn: 0.2579901	total: 9.42s	remaining: 2.56s
# 786:	learn: 0.2577889	total: 9.44s	remaining: 2.55s
# 787:	learn: 0.2576762	total: 9.46s	remaining: 2.55s
# 788:	learn: 0.2575011	total: 9.48s	remaining: 2.54s
# 789:	learn: 0.2572145	total: 9.51s	remaining: 2.53s
# 790:	learn: 0.2569907	total: 9.54s	remaining: 2.52s
# 791:	learn: 0.2567120	total: 9.56s	remaining: 2.51s
# 792:	learn: 0.2565806	total: 9.58s	remaining: 2.5s
# 793:	learn: 0.2564902	total: 9.6s	remaining: 2.49s
# 794:	learn: 0.2562553	total: 9.61s	remaining: 2.48s
# 795:	learn: 0.2561499	total: 9.62s	remaining: 2.47s
# 796:	learn: 0.2560145	total: 9.64s	remaining: 2.45s
# 797:	learn: 0.2558706	total: 9.65s	remaining: 2.44s
# 798:	learn: 0.2556429	total: 9.66s	remaining: 2.43s
# 799:	learn: 0.2555454	total: 9.68s	remaining: 2.42s
# 800:	learn: 0.2554389	total: 9.7s	remaining: 2.41s
# 801:	learn: 0.2553343	total: 9.72s	remaining: 2.4s
# 802:	learn: 0.2551818	total: 9.74s	remaining: 2.39s
# 803:	learn: 0.2550023	total: 9.76s	remaining: 2.38s
# 804:	learn: 0.2547902	total: 9.78s	remaining: 2.37s
# 805:	learn: 0.2546703	total: 9.81s	remaining: 2.36s
# 806:	learn: 0.2545594	total: 9.83s	remaining: 2.35s
# 807:	learn: 0.2543548	total: 9.85s	remaining: 2.34s
# 808:	learn: 0.2542359	total: 9.87s	remaining: 2.33s
# 809:	learn: 0.2540254	total: 9.89s	remaining: 2.32s
# 810:	learn: 0.2538499	total: 9.92s	remaining: 2.31s
# 811:	learn: 0.2535878	total: 9.93s	remaining: 2.3s
# 812:	learn: 0.2533991	total: 9.95s	remaining: 2.29s
# 813:	learn: 0.2533347	total: 9.97s	remaining: 2.28s
# 814:	learn: 0.2531346	total: 10s	remaining: 2.27s
# 815:	learn: 0.2530629	total: 10s	remaining: 2.26s
# 816:	learn: 0.2528335	total: 10s	remaining: 2.25s
# 817:	learn: 0.2525994	total: 10.1s	remaining: 2.24s
# 818:	learn: 0.2524743	total: 10.1s	remaining: 2.23s
# 819:	learn: 0.2523510	total: 10.1s	remaining: 2.22s
# 820:	learn: 0.2522741	total: 10.1s	remaining: 2.2s
# 821:	learn: 0.2520093	total: 10.1s	remaining: 2.19s
# 822:	learn: 0.2518894	total: 10.1s	remaining: 2.18s
# 823:	learn: 0.2515721	total: 10.1s	remaining: 2.17s
# 824:	learn: 0.2515133	total: 10.1s	remaining: 2.15s
# 825:	learn: 0.2513570	total: 10.2s	remaining: 2.14s
# 826:	learn: 0.2511488	total: 10.2s	remaining: 2.13s
# 827:	learn: 0.2510556	total: 10.2s	remaining: 2.11s
# 828:	learn: 0.2509225	total: 10.2s	remaining: 2.1s
# 829:	learn: 0.2508159	total: 10.2s	remaining: 2.09s
# 830:	learn: 0.2506493	total: 10.2s	remaining: 2.08s
# 831:	learn: 0.2505487	total: 10.2s	remaining: 2.06s
# 832:	learn: 0.2503966	total: 10.2s	remaining: 2.05s
# 833:	learn: 0.2502686	total: 10.2s	remaining: 2.04s
# 834:	learn: 0.2501289	total: 10.2s	remaining: 2.02s
# 835:	learn: 0.2498860	total: 10.3s	remaining: 2.01s
# 836:	learn: 0.2497565	total: 10.3s	remaining: 2s
# 837:	learn: 0.2496175	total: 10.3s	remaining: 1.99s
# 838:	learn: 0.2494853	total: 10.3s	remaining: 1.97s
# 839:	learn: 0.2492695	total: 10.3s	remaining: 1.96s
# 840:	learn: 0.2491080	total: 10.3s	remaining: 1.95s
# 841:	learn: 0.2489018	total: 10.3s	remaining: 1.93s
# 842:	learn: 0.2488168	total: 10.3s	remaining: 1.92s
# 843:	learn: 0.2486709	total: 10.3s	remaining: 1.91s
# 844:	learn: 0.2485561	total: 10.3s	remaining: 1.9s
# 845:	learn: 0.2483352	total: 10.3s	remaining: 1.88s
# 846:	learn: 0.2482427	total: 10.4s	remaining: 1.87s
# 847:	learn: 0.2481937	total: 10.4s	remaining: 1.86s
# 848:	learn: 0.2481144	total: 10.4s	remaining: 1.84s
# 849:	learn: 0.2479804	total: 10.4s	remaining: 1.83s
# 850:	learn: 0.2478856	total: 10.4s	remaining: 1.82s
# 851:	learn: 0.2477755	total: 10.4s	remaining: 1.81s
# 852:	learn: 0.2476815	total: 10.4s	remaining: 1.79s
# 853:	learn: 0.2475470	total: 10.4s	remaining: 1.78s
# 854:	learn: 0.2473796	total: 10.4s	remaining: 1.77s
# 855:	learn: 0.2472616	total: 10.4s	remaining: 1.76s
# 856:	learn: 0.2471246	total: 10.4s	remaining: 1.74s
# 857:	learn: 0.2470148	total: 10.5s	remaining: 1.73s
# 858:	learn: 0.2468148	total: 10.5s	remaining: 1.72s
# 859:	learn: 0.2466873	total: 10.5s	remaining: 1.71s
# 860:	learn: 0.2465908	total: 10.5s	remaining: 1.69s
# 861:	learn: 0.2464020	total: 10.5s	remaining: 1.68s
# 862:	learn: 0.2462857	total: 10.5s	remaining: 1.67s
# 863:	learn: 0.2461574	total: 10.5s	remaining: 1.65s
# 864:	learn: 0.2459416	total: 10.5s	remaining: 1.64s
# 865:	learn: 0.2457676	total: 10.5s	remaining: 1.63s
# 866:	learn: 0.2456144	total: 10.5s	remaining: 1.62s
# 867:	learn: 0.2454582	total: 10.6s	remaining: 1.6s
# 868:	learn: 0.2453730	total: 10.6s	remaining: 1.59s
# 869:	learn: 0.2453008	total: 10.6s	remaining: 1.58s
# 870:	learn: 0.2451240	total: 10.6s	remaining: 1.57s
# 871:	learn: 0.2450228	total: 10.6s	remaining: 1.55s
# 872:	learn: 0.2448807	total: 10.6s	remaining: 1.54s
# 873:	learn: 0.2446363	total: 10.6s	remaining: 1.53s
# 874:	learn: 0.2445333	total: 10.6s	remaining: 1.52s
# 875:	learn: 0.2443423	total: 10.6s	remaining: 1.5s
# 876:	learn: 0.2442146	total: 10.6s	remaining: 1.49s
# 877:	learn: 0.2440498	total: 10.6s	remaining: 1.48s
# 878:	learn: 0.2439321	total: 10.7s	remaining: 1.47s
# 879:	learn: 0.2437842	total: 10.7s	remaining: 1.45s
# 880:	learn: 0.2436023	total: 10.7s	remaining: 1.44s
# 881:	learn: 0.2435111	total: 10.7s	remaining: 1.43s
# 882:	learn: 0.2433865	total: 10.7s	remaining: 1.42s
# 883:	learn: 0.2432826	total: 10.7s	remaining: 1.4s
# 884:	learn: 0.2432192	total: 10.7s	remaining: 1.39s
# 885:	learn: 0.2429892	total: 10.7s	remaining: 1.38s
# 886:	learn: 0.2428516	total: 10.7s	remaining: 1.37s
# 887:	learn: 0.2426410	total: 10.7s	remaining: 1.35s
# 888:	learn: 0.2425578	total: 10.8s	remaining: 1.34s
# 889:	learn: 0.2424727	total: 10.8s	remaining: 1.33s
# 890:	learn: 0.2423665	total: 10.8s	remaining: 1.32s
# 891:	learn: 0.2422255	total: 10.8s	remaining: 1.31s
# 892:	learn: 0.2420485	total: 10.8s	remaining: 1.29s
# 893:	learn: 0.2419053	total: 10.8s	remaining: 1.28s
# 894:	learn: 0.2417957	total: 10.8s	remaining: 1.27s
# 895:	learn: 0.2417325	total: 10.8s	remaining: 1.26s
# 896:	learn: 0.2415874	total: 10.8s	remaining: 1.25s
# 897:	learn: 0.2414973	total: 10.9s	remaining: 1.23s
# 898:	learn: 0.2413619	total: 10.9s	remaining: 1.22s
# 899:	learn: 0.2412204	total: 10.9s	remaining: 1.21s
# 900:	learn: 0.2410635	total: 10.9s	remaining: 1.2s
# 901:	learn: 0.2409549	total: 10.9s	remaining: 1.18s
# 902:	learn: 0.2408534	total: 10.9s	remaining: 1.17s
# 903:	learn: 0.2407171	total: 10.9s	remaining: 1.16s
# 904:	learn: 0.2405957	total: 10.9s	remaining: 1.15s
# 905:	learn: 0.2404762	total: 10.9s	remaining: 1.13s
# 906:	learn: 0.2403713	total: 10.9s	remaining: 1.12s
# 907:	learn: 0.2401701	total: 10.9s	remaining: 1.11s
# 908:	learn: 0.2398787	total: 11s	remaining: 1.1s
# 909:	learn: 0.2397239	total: 11s	remaining: 1.08s
# 910:	learn: 0.2396043	total: 11s	remaining: 1.07s
# 911:	learn: 0.2394515	total: 11s	remaining: 1.06s
# 912:	learn: 0.2393641	total: 11s	remaining: 1.05s
# 913:	learn: 0.2392395	total: 11s	remaining: 1.03s
# 914:	learn: 0.2390877	total: 11s	remaining: 1.02s
# 915:	learn: 0.2390080	total: 11s	remaining: 1.01s
# 916:	learn: 0.2387724	total: 11s	remaining: 999ms
# 917:	learn: 0.2386977	total: 11s	remaining: 986ms
# 918:	learn: 0.2386194	total: 11.1s	remaining: 974ms
# 919:	learn: 0.2384345	total: 11.1s	remaining: 962ms
# 920:	learn: 0.2383157	total: 11.1s	remaining: 949ms
# 921:	learn: 0.2382257	total: 11.1s	remaining: 937ms
# 922:	learn: 0.2379662	total: 11.1s	remaining: 925ms
# 923:	learn: 0.2378019	total: 11.1s	remaining: 913ms
# 924:	learn: 0.2377081	total: 11.1s	remaining: 900ms
# 925:	learn: 0.2376077	total: 11.1s	remaining: 888ms
# 926:	learn: 0.2374762	total: 11.1s	remaining: 876ms
# 927:	learn: 0.2373009	total: 11.1s	remaining: 864ms
# 928:	learn: 0.2372202	total: 11.1s	remaining: 852ms
# 929:	learn: 0.2370908	total: 11.2s	remaining: 840ms
# 930:	learn: 0.2369577	total: 11.2s	remaining: 827ms
# 931:	learn: 0.2368729	total: 11.2s	remaining: 815ms
# 932:	learn: 0.2366989	total: 11.2s	remaining: 803ms
# 933:	learn: 0.2365327	total: 11.2s	remaining: 791ms
# 934:	learn: 0.2363917	total: 11.2s	remaining: 778ms
# 935:	learn: 0.2362244	total: 11.2s	remaining: 766ms
# 936:	learn: 0.2360850	total: 11.2s	remaining: 754ms
# 937:	learn: 0.2359951	total: 11.2s	remaining: 742ms
# 938:	learn: 0.2358575	total: 11.2s	remaining: 730ms
# 939:	learn: 0.2357816	total: 11.2s	remaining: 718ms
# 940:	learn: 0.2356816	total: 11.3s	remaining: 705ms
# 941:	learn: 0.2355708	total: 11.3s	remaining: 693ms
# 942:	learn: 0.2354294	total: 11.3s	remaining: 681ms
# 943:	learn: 0.2353171	total: 11.3s	remaining: 669ms
# 944:	learn: 0.2351649	total: 11.3s	remaining: 657ms
# 945:	learn: 0.2350684	total: 11.3s	remaining: 645ms
# 946:	learn: 0.2350128	total: 11.3s	remaining: 633ms
# 947:	learn: 0.2349160	total: 11.3s	remaining: 621ms
# 948:	learn: 0.2347039	total: 11.3s	remaining: 609ms
# 949:	learn: 0.2345764	total: 11.3s	remaining: 596ms
# 950:	learn: 0.2344885	total: 11.3s	remaining: 585ms
# 951:	learn: 0.2343931	total: 11.4s	remaining: 573ms
# 952:	learn: 0.2342964	total: 11.4s	remaining: 561ms
# 953:	learn: 0.2342228	total: 11.4s	remaining: 549ms
# 954:	learn: 0.2339712	total: 11.4s	remaining: 537ms
# 955:	learn: 0.2338926	total: 11.4s	remaining: 525ms
# 956:	learn: 0.2337453	total: 11.4s	remaining: 513ms
# 957:	learn: 0.2333702	total: 11.4s	remaining: 501ms
# 958:	learn: 0.2332671	total: 11.4s	remaining: 488ms
# 959:	learn: 0.2331557	total: 11.4s	remaining: 476ms
# 960:	learn: 0.2330410	total: 11.4s	remaining: 464ms
# 961:	learn: 0.2328870	total: 11.5s	remaining: 452ms
# 962:	learn: 0.2327861	total: 11.5s	remaining: 440ms
# 963:	learn: 0.2326426	total: 11.5s	remaining: 428ms
# 964:	learn: 0.2325238	total: 11.5s	remaining: 416ms
# 965:	learn: 0.2324714	total: 11.5s	remaining: 404ms
# 966:	learn: 0.2323323	total: 11.5s	remaining: 392ms
# 967:	learn: 0.2322121	total: 11.5s	remaining: 380ms
# 968:	learn: 0.2321300	total: 11.5s	remaining: 368ms
# 969:	learn: 0.2319936	total: 11.5s	remaining: 356ms
# 970:	learn: 0.2318885	total: 11.5s	remaining: 344ms
# 971:	learn: 0.2317805	total: 11.5s	remaining: 332ms
# 972:	learn: 0.2317028	total: 11.6s	remaining: 321ms
# 973:	learn: 0.2315848	total: 11.6s	remaining: 309ms
# 974:	learn: 0.2314870	total: 11.6s	remaining: 297ms
# 975:	learn: 0.2313394	total: 11.6s	remaining: 285ms
# 976:	learn: 0.2312317	total: 11.6s	remaining: 273ms
# 977:	learn: 0.2310906	total: 11.6s	remaining: 261ms
# 978:	learn: 0.2309702	total: 11.6s	remaining: 249ms
# 979:	learn: 0.2308449	total: 11.6s	remaining: 237ms
# 980:	learn: 0.2307597	total: 11.6s	remaining: 225ms
# 981:	learn: 0.2305942	total: 11.6s	remaining: 213ms
# 982:	learn: 0.2303429	total: 11.6s	remaining: 201ms
# 983:	learn: 0.2302488	total: 11.7s	remaining: 190ms
# 984:	learn: 0.2301889	total: 11.7s	remaining: 178ms
# 985:	learn: 0.2300723	total: 11.7s	remaining: 166ms
# 986:	learn: 0.2298819	total: 11.7s	remaining: 154ms
# 987:	learn: 0.2297758	total: 11.7s	remaining: 142ms
# 988:	learn: 0.2296552	total: 11.7s	remaining: 130ms
# 989:	learn: 0.2294040	total: 11.7s	remaining: 118ms
# 990:	learn: 0.2292769	total: 11.7s	remaining: 106ms
# 991:	learn: 0.2291583	total: 11.7s	remaining: 94.6ms
# 992:	learn: 0.2290351	total: 11.7s	remaining: 82.7ms
# 993:	learn: 0.2289730	total: 11.7s	remaining: 70.9ms
# 994:	learn: 0.2287263	total: 11.8s	remaining: 59.1ms
# 995:	learn: 0.2286294	total: 11.8s	remaining: 47.3ms
# 996:	learn: 0.2284145	total: 11.8s	remaining: 35.5ms
# 997:	learn: 0.2283066	total: 11.8s	remaining: 23.6ms
# 998:	learn: 0.2281362	total: 11.8s	remaining: 11.8ms
# 999:	learn: 0.2280357	total: 11.8s	remaining: 0us

# %%
df_cross_val = pd.DataFrame(scores, index = ['test_score', 'train_score', 'fit_time']).T
df_cross_val.sort_values(by = ['test_score'], ascending = False, inplace = True)
df_cross_val
# Out:
#                          test_score  train_score   fit_time
# Random Forest              0.885629     0.999659   2.612691
# CatBoost                   0.872914     0.940098  12.976030
# Gradient Boosting          0.804948     0.823816  10.622377
# RBF SVM                    0.664604     0.668975   4.925158
# Logistic Regression        0.597906     0.598486   0.199257
# Linear SVM                 0.593356     0.593208   4.621633
# Gaussian Naive Bayes       0.544917     0.546145   0.025355
# Categorical Naive Bayes    0.149256     0.149289   0.053656

# %% [markdown]
# Среди всех моделей лучший результат показала модель Random Forest, но есть признаки переобучения. Дальше поработаем именно с этой моделью.

# %% [markdown]
# ## Сравнение моделей

# %% [markdown]
# ### Random Forest

# %% [markdown]
# #### **Кривая обучения**

# %%
model = RandomForestClassifier()
visualizer = LearningCurve(model, train_sizes=np.linspace(0.1, 1.0, 10)).fit(X_train, y_train).show()

# %% [markdown]
# Как и было предположено раньше, по графику кривой обучения видно, что у модели присутствуют признаки переобучения.

# %% [markdown]
# #### **Подбор гиперпараметров**

# %%
params_rf = {'n_estimators': [10, 50, 100, 500],
             'max_depth': [None, 5, 10, 50, 100],
             'min_samples_split': [2, 5, 10]
}

grid_model_rf = GridSearchCV(estimator=model, param_grid=params_rf, scoring='f1_macro', cv=5, return_train_score=True)

grid_model_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [None, 5, 10, 50, 100],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [10, 50, 100, 500]},
#              return_train_score=True, scoring='f1_macro')

# %%
cv_info = pd.DataFrame(grid_model_rf.cv_results_)[['params', 'mean_test_score', 'mean_train_score', 'rank_test_score']]
cv_info.sort_values(by = 'rank_test_score', ascending = True, inplace = True)
cv_info.head()
# Out:
#                                                params  mean_test_score  \
# 51  {'max_depth': 100, 'min_samples_split': 2, 'n_...         0.886460
# 3   {'max_depth': None, 'min_samples_split': 2, 'n...         0.886101
# 2   {'max_depth': None, 'min_samples_split': 2, 'n...         0.885700
# 39  {'max_depth': 50, 'min_samples_split': 2, 'n_e...         0.885641
# 50  {'max_depth': 100, 'min_samples_split': 2, 'n_...         0.885466
#
#     mean_train_score  rank_test_score
# 51          0.999659                1
# 3           0.999659                2
# 2           0.999659                3
# 39          0.999659                4
# 50          0.999659                5

# %%
best_params = dict(cv_info.loc[3].params)
pd.DataFrame(best_params.values(), index = best_params.keys(), columns = ['Лучшие параметры'])
# Out:
#                    Лучшие параметры
# max_depth                       NaN
# min_samples_split               2.0
# n_estimators                  500.0

# %% [markdown]
# #### **Метрики**

# %%
best_model_rf = grid_model_rf.best_estimator_
best_model_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=100, n_estimators=500)

# %%
y_pred = best_model_rf.predict(X_test)

acc_rf = accuracy_score(y_test, y_pred)
pr_rf = precision_score(y_test, y_pred, average = 'macro')
rc_rf = recall_score(y_test, y_pred, average = 'macro')
f1_rf = f1_score(y_test, y_pred, average = 'macro')

metrics_rf = pd.DataFrame({'Random Forest': [acc_rf, pr_rf, rc_rf, f1_rf]}, index = ['Accuracy', 'Precision', 'Recall', 'F1'])
metrics_rf
# Out:
#            Random Forest
# Accuracy        0.883900
# Precision       0.884413
# Recall          0.883885
# F1              0.883998

# %% [markdown]
# Построим матрицу ошибок для лучшего понимания того, какие классы модель предсказывает правильно:

# %%
plt.figure(figsize = (10,6))
sns.heatmap(confusion_matrix(y_test, y_pred), cmap="RdBu", annot = True)
plt.show()

# %% [markdown]
# Можно сказать, что модель неплохо справляется с предсказыванием класса, ошибок не так много.

# %% [markdown]
# Проанализируем кривые ROC-AUC и PR-AUC:

# %%
cls = pd.unique(y_train)
visualizer_roc = ROCAUC(best_model_rf, classes = cls)
visualizer_roc.fit(X_train, y_train)
visualizer_roc.score(X_test, y_test)
visualizer_roc.show()
# Out:
# <Axes: title={'center': 'ROC Curves for RandomForestClassifier'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %% [markdown]
# На графике ROC кривых представленны кривые и метрики для каждого из четырех классов. Так как данный показатель применим только к бинарной классификации, алгоритм рассчитывает метрики для каждого класса, обозначая нужный класс за 0, а остальные за 1, тем самым приводя к бинарной классификации.
#
# Показатель AUC−ROC является мерой качества классификатора относительно идеального. Значение показателя в пределах [0.95, 1] говорит о хорошем качестве модели.

# %%
visualizer_pr = PrecisionRecallCurve(best_model_rf, classes = cls)
visualizer_pr.fit(X_train, y_train)
visualizer_pr.score(X_test, y_test)
visualizer_pr.show()
# Out:
# <Axes: title={'center': 'Precision-Recall Curve for RandomForestClassifier'}, xlabel='Recall', ylabel='Precision'>

# %% [markdown]
# PR-AUC - метрика, отражает качество классификатора и позволяет сравнивать кривые, соответствующие различным балансам классов и значениям порога. Чем больше площадь, тем лучше работает модель. В данном случае метрика равна 0.97, что говорит о хорошем качестве модели.

# %% [markdown]
# #Вывод

# %% [markdown]
# Таким образом, RandomForest достаточно хорошо справляется с предсказыванием класса. Такой вывод мы сделали, проведя кросс-валидацию (где выбрали лучшую модель) и подобрав лучшие параметры.
